# %%
import tensorflow as tf
from konlpy.tag import Twitter
import numpy as np
import gensim
import time

# %%
def read_data(filename):    
    with open(filename, 'r',encoding='utf-8') as f:
        data = [line.split('\t') for line in f.read().splitlines()]        
        data = data[1:]   # header 제외 #    
    return data 
    
train_data = read_data('data/ratings_train.txt')
# test_data = read_data('data/ratings_test.txt')
len(train_data)
# Out:
# 150000

# %%
twitter = Twitter() 

def tokenize(doc):

    return ['/'.join(t) for t in twitter.pos(doc, norm=True, stem=True)]

tokens = [tokenize(row[1]) for row in train_data]

# %%
model = gensim.models.Word2Vec(size=300, sg=1, alpha=0.025, min_alpha=0.025, seed=410)
model.build_vocab(tokens)
model.train(tokens, model.corpus_count, epochs=model.epochs)
# Out:
# (8612010, 10972680)

# %%
# '외계인/Noun' in model.wv.vocab

# %%
model.save('word2vec.model')

# %%
model = gensim.models.word2vec.Word2Vec.load('word2vec.model')

# %%
len(model.wv.vocab)

def convert2Vec(model, doc):  ## Convert corpus into vectors
    word_vec = []
    word_num = 0
    unk_num = 0
#     print('doc : ', doc)
    for sent in doc:
#         print('sent : ', sent)
        sub = []
        for word in sent:
            word_num += 1
            if(word in model.wv.vocab):
#                 print('word in sent')
                sub.append(model.wv[word])
            else:
                unk_num += 1
#                 print('word not in sent')
                sub.append(np.zeros(300)) ## used for OOV words
        word_vec.append(sub)
    print('word_num :', word_num, 'unk_num :', unk_num)
    return word_vec

# %%
tokens = [[tokenize(row[1]),int(row[2])] for row in train_data if tokenize(row[1]) != []]
tokens = np.array(tokens)
train_X = tokens[:,0]
train_Y = tokens[:,[-1]]
train_X = convert2Vec(model, train_X)
# train_Y = np.array([[y] for y in train_Y])
seq_length = [len(x) for x in train_X]
maxseq_length = max(seq_length)
maxseq_length
# Out:
# word_num : 2194536 unk_num : 53296
# 95

# %%
def zero_padding(maxseq_length, seq):
#     print(len(seq))
    zero_pad = np.zeros((maxseq_length) * 300)
    seq_flat = np.reshape(seq, [-1])
#     print(len(seq_flat))
    zero_pad[0:len(seq) * 300] = seq_flat
#     print(len(zero_pad))
    return zero_pad
train_X = [zero_padding(maxseq_length, seq) for seq in train_X]
len(train_X[0])
# Out:
# 28500

# %%
X = tf.placeholder(tf.float32, shape=[None, maxseq_length * 300])
Y = tf.placeholder(tf.float32, shape=[None, 1])

# %%
W = tf.Variable(tf.random_normal([maxseq_length * 300, 1]), name='weight1')
b = tf.Variable(tf.random_normal([1]), name='bias')

# %%
hypothesis = tf.sigmoid(tf.matmul(X, W) + b)

# %%
# cost = -tf.reduce_mean(Y * tf.log(hypothesis) + (1 - Y) *
#                        tf.log(1 - hypothesis))
cost = -tf.reduce_mean(Y * tf.log(hypothesis + 1e-7) + (1 - Y) * tf.log(1 - hypothesis + 1e-7))
cost_summ = tf.summary.scalar("cost", cost)

# %%
train = tf.train.AdamOptimizer(learning_rate=0.001).minimize(cost)

# %%
predicted = tf.cast(hypothesis > 0.5, dtype=tf.float32)
accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, Y), dtype=tf.float32))
acc_summ = tf.summary.scalar("accuracy", accuracy)

# %%
training_epochs = 10
Batch_size = 32
total_batch = int(len(train_X) / Batch_size)
save_path = './saved/model'
saver = tf.train.Saver()

with tf.Session() as sess:
    merged_summary = tf.summary.merge_all()
    writer = tf.summary.FileWriter("./logs/logistic")
    writer.add_graph(sess.graph)  # Show the graph
    
    start_time = time.time()

    # Initialize TensorFlow variables
    sess.run(tf.global_variables_initializer())

    for epoch in range(training_epochs):

        avg_loss = 0
        for step in range(total_batch):

            train_batch_X = train_X[step*Batch_size : step*Batch_size+Batch_size]
            train_batch_Y = train_Y[step*Batch_size : step*Batch_size+Batch_size]
            
            cost_val, _ = sess.run([cost, train], feed_dict={X: train_batch_X, Y: train_batch_Y})
            avg_loss += cost_val
            acc = sess.run(accuracy , feed_dict={X: train_batch_X, Y: train_batch_Y})
            print('Batch : ', step + 1, '/', total_batch,
                  ', BCE in this minibatch: ', cost_val, 'accuracy: ', float(acc))

#         summary = sess.run(merged_summary, feed_dict={X: train_X, Y: train_Y})
#         writer.add_summary(summary, global_step=epoch)

#         acc = sess.run(accuracy , feed_dict={X: train_X, Y: train_Y})
        print('epoch:', epoch, ' train_loss:', float(avg_loss/total_batch))
#         print('epoch:', epoch, ' train_loss:', float(avg_loss/total_batch), ' accuracy: ', float(acc))
        saver.save(sess, save_path, epoch)
        
    duration = time.time() - start_time
    minute = int(duration / 60)
    print('learning finish, minutes:', minute)
# Out:
# Batch :  1 / 4687 , BCE in this minibatch:  4.604854 accuracy:  0.46875
# Batch :  2 / 4687 , BCE in this minibatch:  3.2398477 accuracy:  0.46875
# Batch :  3 / 4687 , BCE in this minibatch:  3.820993 accuracy:  0.5
# Batch :  4 / 4687 , BCE in this minibatch:  3.9597986 accuracy:  0.625
# Batch :  5 / 4687 , BCE in this minibatch:  4.620019 accuracy:  0.375
# Batch :  6 / 4687 , BCE in this minibatch:  4.4803514 accuracy:  0.5625
# Batch :  7 / 4687 , BCE in this minibatch:  4.6787577 accuracy:  0.5625
# Batch :  8 / 4687 , BCE in this minibatch:  5.2917404 accuracy:  0.4375
# Batch :  9 / 4687 , BCE in this minibatch:  4.562058 accuracy:  0.4375
# Batch :  10 / 4687 , BCE in this minibatch:  3.7259886 accuracy:  0.59375
# Batch :  11 / 4687 , BCE in this minibatch:  5.0592813 accuracy:  0.5
# Batch :  12 / 4687 , BCE in this minibatch:  2.4085417 accuracy:  0.65625
# Batch :  13 / 4687 , BCE in this minibatch:  2.407361 accuracy:  0.625
# Batch :  14 / 4687 , BCE in this minibatch:  3.2252138 accuracy:  0.5625
# Batch :  15 / 4687 , BCE in this minibatch:  3.2177005 accuracy:  0.65625
# Batch :  16 / 4687 , BCE in this minibatch:  5.059749 accuracy:  0.4375
# Batch :  17 / 4687 , BCE in this minibatch:  3.7856503 accuracy:  0.5625
# Batch :  18 / 4687 , BCE in this minibatch:  5.457282 accuracy:  0.40625
# Batch :  19 / 4687 , BCE in this minibatch:  2.4910603 accuracy:  0.625
# Batch :  20 / 4687 , BCE in this minibatch:  3.5315108 accuracy:  0.5
# Batch :  21 / 4687 , BCE in this minibatch:  3.97723 accuracy:  0.4375
# Batch :  22 / 4687 , BCE in this minibatch:  4.2931232 accuracy:  0.40625
# Batch :  23 / 4687 , BCE in this minibatch:  5.117588 accuracy:  0.40625
# Batch :  24 / 4687 , BCE in this minibatch:  3.6620858 accuracy:  0.5625
# Batch :  25 / 4687 , BCE in this minibatch:  1.8810643 accuracy:  0.625
# Batch :  26 / 4687 , BCE in this minibatch:  5.1733894 accuracy:  0.5
# Batch :  27 / 4687 , BCE in this minibatch:  4.095551 accuracy:  0.53125
# Batch :  28 / 4687 , BCE in this minibatch:  5.4106984 accuracy:  0.4375
# Batch :  29 / 4687 , BCE in this minibatch:  3.4003644 accuracy:  0.53125
# Batch :  30 / 4687 , BCE in this minibatch:  3.5538714 accuracy:  0.53125
# Batch :  31 / 4687 , BCE in this minibatch:  3.796821 accuracy:  0.4375
# Batch :  32 / 4687 , BCE in this minibatch:  4.620499 accuracy:  0.375
# Batch :  33 / 4687 , BCE in this minibatch:  3.4909368 accuracy:  0.625
# Batch :  34 / 4687 , BCE in this minibatch:  4.0732822 accuracy:  0.59375
# Batch :  35 / 4687 , BCE in this minibatch:  5.1206903 accuracy:  0.5
# Batch :  36 / 4687 , BCE in this minibatch:  3.4625943 accuracy:  0.5625
# Batch :  37 / 4687 , BCE in this minibatch:  3.7669194 accuracy:  0.53125
# Batch :  38 / 4687 , BCE in this minibatch:  2.1923342 accuracy:  0.625
# Batch :  39 / 4687 , BCE in this minibatch:  4.5363026 accuracy:  0.5625
# Batch :  40 / 4687 , BCE in this minibatch:  3.0875797 accuracy:  0.5625
# Batch :  41 / 4687 , BCE in this minibatch:  3.4940631 accuracy:  0.46875
# Batch :  42 / 4687 , BCE in this minibatch:  4.494626 accuracy:  0.5
# Batch :  43 / 4687 , BCE in this minibatch:  2.0752087 accuracy:  0.5625
# Batch :  44 / 4687 , BCE in this minibatch:  2.7898598 accuracy:  0.5625
# Batch :  45 / 4687 , BCE in this minibatch:  4.248922 accuracy:  0.53125
# Batch :  46 / 4687 , BCE in this minibatch:  4.2329993 accuracy:  0.5625
# Batch :  47 / 4687 , BCE in this minibatch:  3.8255236 accuracy:  0.5625
# Batch :  48 / 4687 , BCE in this minibatch:  4.4972744 accuracy:  0.40625
# Batch :  49 / 4687 , BCE in this minibatch:  2.603232 accuracy:  0.65625
# Batch :  50 / 4687 , BCE in this minibatch:  2.5599098 accuracy:  0.5625
# Batch :  51 / 4687 , BCE in this minibatch:  4.3933177 accuracy:  0.4375
# Batch :  52 / 4687 , BCE in this minibatch:  3.7866993 accuracy:  0.5625
# Batch :  53 / 4687 , BCE in this minibatch:  2.701424 accuracy:  0.59375
# Batch :  54 / 4687 , BCE in this minibatch:  3.4572325 accuracy:  0.5625
# Batch :  55 / 4687 , BCE in this minibatch:  6.0478215 accuracy:  0.40625
# Batch :  56 / 4687 , BCE in this minibatch:  4.753686 accuracy:  0.53125
# Batch :  57 / 4687 , BCE in this minibatch:  4.091604 accuracy:  0.5
# Batch :  58 / 4687 , BCE in this minibatch:  3.8788414 accuracy:  0.5625
# Batch :  59 / 4687 , BCE in this minibatch:  4.3371444 accuracy:  0.46875
# Batch :  60 / 4687 , BCE in this minibatch:  4.145138 accuracy:  0.4375
# Batch :  61 / 4687 , BCE in this minibatch:  3.7802882 accuracy:  0.53125
# Batch :  62 / 4687 , BCE in this minibatch:  3.4037309 accuracy:  0.5
# Batch :  63 / 4687 , BCE in this minibatch:  4.646464 accuracy:  0.40625
# Batch :  64 / 4687 , BCE in this minibatch:  2.6358953 accuracy:  0.625
# Batch :  65 / 4687 , BCE in this minibatch:  4.6482472 accuracy:  0.40625
# Batch :  66 / 4687 , BCE in this minibatch:  4.0352316 accuracy:  0.65625
# Batch :  67 / 4687 , BCE in this minibatch:  2.9175353 accuracy:  0.59375
# Batch :  68 / 4687 , BCE in this minibatch:  3.9707189 accuracy:  0.53125
# Batch :  69 / 4687 , BCE in this minibatch:  3.6037645 accuracy:  0.6875
# Batch :  70 / 4687 , BCE in this minibatch:  3.90693 accuracy:  0.5
# Batch :  71 / 4687 , BCE in this minibatch:  3.0716398 accuracy:  0.53125
# Batch :  72 / 4687 , BCE in this minibatch:  2.9048471 accuracy:  0.59375
# Batch :  73 / 4687 , BCE in this minibatch:  2.5046673 accuracy:  0.65625
# Batch :  74 / 4687 , BCE in this minibatch:  5.0516295 accuracy:  0.34375
# Batch :  75 / 4687 , BCE in this minibatch:  3.7854784 accuracy:  0.5
# Batch :  76 / 4687 , BCE in this minibatch:  3.3619778 accuracy:  0.625
# Batch :  77 / 4687 , BCE in this minibatch:  3.30917 accuracy:  0.625
# Batch :  78 / 4687 , BCE in this minibatch:  3.3791845 accuracy:  0.5625
# Batch :  79 / 4687 , BCE in this minibatch:  2.2034435 accuracy:  0.75
# Batch :  80 / 4687 , BCE in this minibatch:  2.868951 accuracy:  0.65625
# Batch :  81 / 4687 , BCE in this minibatch:  3.1935208 accuracy:  0.46875
# Batch :  82 / 4687 , BCE in this minibatch:  3.382246 accuracy:  0.53125
# Batch :  83 / 4687 , BCE in this minibatch:  2.429475 accuracy:  0.59375
# Batch :  84 / 4687 , BCE in this minibatch:  4.633362 accuracy:  0.4375
# Batch :  85 / 4687 , BCE in this minibatch:  2.1711 accuracy:  0.46875
# Batch :  86 / 4687 , BCE in this minibatch:  3.235661 accuracy:  0.59375
# Batch :  87 / 4687 , BCE in this minibatch:  4.29591 accuracy:  0.4375
# Batch :  88 / 4687 , BCE in this minibatch:  3.2104683 accuracy:  0.59375
# Batch :  89 / 4687 , BCE in this minibatch:  1.4120793 accuracy:  0.6875
# Batch :  90 / 4687 , BCE in this minibatch:  4.972254 accuracy:  0.53125
# Batch :  91 / 4687 , BCE in this minibatch:  2.4625535 accuracy:  0.59375
# Batch :  92 / 4687 , BCE in this minibatch:  2.3012645 accuracy:  0.75
# Batch :  93 / 4687 , BCE in this minibatch:  5.32298 accuracy:  0.25
# Batch :  94 / 4687 , BCE in this minibatch:  2.6636667 accuracy:  0.59375
# Batch :  95 / 4687 , BCE in this minibatch:  4.4655614 accuracy:  0.5
# Batch :  96 / 4687 , BCE in this minibatch:  3.9410677 accuracy:  0.53125
# Batch :  97 / 4687 , BCE in this minibatch:  3.4497128 accuracy:  0.5625
# Batch :  98 / 4687 , BCE in this minibatch:  3.8595965 accuracy:  0.4375
# Batch :  99 / 4687 , BCE in this minibatch:  3.9601417 accuracy:  0.5
# Batch :  100 / 4687 , BCE in this minibatch:  2.3088279 accuracy:  0.59375
# Batch :  101 / 4687 , BCE in this minibatch:  4.807971 accuracy:  0.40625
# Batch :  102 / 4687 , BCE in this minibatch:  2.775465 accuracy:  0.6875
# Batch :  103 / 4687 , BCE in this minibatch:  3.0728211 accuracy:  0.625
# Batch :  104 / 4687 , BCE in this minibatch:  4.0724454 accuracy:  0.46875
# Batch :  105 / 4687 , BCE in this minibatch:  3.4543881 accuracy:  0.59375
# Batch :  106 / 4687 , BCE in this minibatch:  2.5940466 accuracy:  0.5625
# Batch :  107 / 4687 , BCE in this minibatch:  3.1903014 accuracy:  0.46875
# Batch :  108 / 4687 , BCE in this minibatch:  3.9292762 accuracy:  0.40625
# Batch :  109 / 4687 , BCE in this minibatch:  3.975182 accuracy:  0.53125
# Batch :  110 / 4687 , BCE in this minibatch:  2.6350677 accuracy:  0.53125
# Batch :  111 / 4687 , BCE in this minibatch:  2.184942 accuracy:  0.65625
# Batch :  112 / 4687 , BCE in this minibatch:  3.7060905 accuracy:  0.5
# Batch :  113 / 4687 , BCE in this minibatch:  3.067656 accuracy:  0.53125
# Batch :  114 / 4687 , BCE in this minibatch:  3.3900218 accuracy:  0.5
# Batch :  115 / 4687 , BCE in this minibatch:  6.046198 accuracy:  0.40625
# Batch :  116 / 4687 , BCE in this minibatch:  3.180975 accuracy:  0.59375
# Batch :  117 / 4687 , BCE in this minibatch:  2.4167793 accuracy:  0.53125
# Batch :  118 / 4687 , BCE in this minibatch:  1.9988208 accuracy:  0.71875
# Batch :  119 / 4687 , BCE in this minibatch:  2.4999204 accuracy:  0.625
# Batch :  120 / 4687 , BCE in this minibatch:  4.8381257 accuracy:  0.40625
# Batch :  121 / 4687 , BCE in this minibatch:  3.723713 accuracy:  0.4375
# Batch :  122 / 4687 , BCE in this minibatch:  3.51572 accuracy:  0.5
# Batch :  123 / 4687 , BCE in this minibatch:  4.50867 accuracy:  0.46875
# Batch :  124 / 4687 , BCE in this minibatch:  3.5146303 accuracy:  0.5625
# Batch :  125 / 4687 , BCE in this minibatch:  3.9102435 accuracy:  0.5
# Batch :  126 / 4687 , BCE in this minibatch:  2.4197407 accuracy:  0.625
# Batch :  127 / 4687 , BCE in this minibatch:  3.1699286 accuracy:  0.59375
# Batch :  128 / 4687 , BCE in this minibatch:  3.058765 accuracy:  0.5625
# Batch :  129 / 4687 , BCE in this minibatch:  2.8471253 accuracy:  0.6875
# Batch :  130 / 4687 , BCE in this minibatch:  3.4819012 accuracy:  0.4375
# Batch :  131 / 4687 , BCE in this minibatch:  5.465709 accuracy:  0.4375
# Batch :  132 / 4687 , BCE in this minibatch:  4.624748 accuracy:  0.5
# Batch :  133 / 4687 , BCE in this minibatch:  4.3445773 accuracy:  0.5625
# Batch :  134 / 4687 , BCE in this minibatch:  5.5274677 accuracy:  0.375
# Batch :  135 / 4687 , BCE in this minibatch:  3.0026999 accuracy:  0.5625
# Batch :  136 / 4687 , BCE in this minibatch:  4.9676495 accuracy:  0.375
# Batch :  137 / 4687 , BCE in this minibatch:  2.8756652 accuracy:  0.5625
# Batch :  138 / 4687 , BCE in this minibatch:  3.6413116 accuracy:  0.5
# Batch :  139 / 4687 , BCE in this minibatch:  3.3144379 accuracy:  0.59375
# Batch :  140 / 4687 , BCE in this minibatch:  2.797258 accuracy:  0.4375
# Batch :  141 / 4687 , BCE in this minibatch:  3.1506636 accuracy:  0.65625
# Batch :  142 / 4687 , BCE in this minibatch:  2.94797 accuracy:  0.5625
# Batch :  143 / 4687 , BCE in this minibatch:  3.24251 accuracy:  0.59375
# Batch :  144 / 4687 , BCE in this minibatch:  4.3062143 accuracy:  0.5
# Batch :  145 / 4687 , BCE in this minibatch:  4.605136 accuracy:  0.40625
# Batch :  146 / 4687 , BCE in this minibatch:  3.1815524 accuracy:  0.625
# Batch :  147 / 4687 , BCE in this minibatch:  2.7653255 accuracy:  0.46875
# Batch :  148 / 4687 , BCE in this minibatch:  2.4213772 accuracy:  0.71875
# Batch :  149 / 4687 , BCE in this minibatch:  2.4170637 accuracy:  0.65625
# Batch :  150 / 4687 , BCE in this minibatch:  4.0990667 accuracy:  0.53125
# Batch :  151 / 4687 , BCE in this minibatch:  3.6368062 accuracy:  0.46875
# Batch :  152 / 4687 , BCE in this minibatch:  1.7800341 accuracy:  0.53125
# Batch :  153 / 4687 , BCE in this minibatch:  4.998077 accuracy:  0.40625
# Batch :  154 / 4687 , BCE in this minibatch:  2.6371083 accuracy:  0.53125
# Batch :  155 / 4687 , BCE in this minibatch:  2.548118 accuracy:  0.59375
# Batch :  156 / 4687 , BCE in this minibatch:  2.987028 accuracy:  0.625
# Batch :  157 / 4687 , BCE in this minibatch:  2.6116657 accuracy:  0.59375
# Batch :  158 / 4687 , BCE in this minibatch:  3.0234854 accuracy:  0.5625
# Batch :  159 / 4687 , BCE in this minibatch:  5.9245143 accuracy:  0.3125
# Batch :  160 / 4687 , BCE in this minibatch:  3.2753696 accuracy:  0.4375
# Batch :  161 / 4687 , BCE in this minibatch:  2.2609508 accuracy:  0.625
# Batch :  162 / 4687 , BCE in this minibatch:  2.9667158 accuracy:  0.53125
# Batch :  163 / 4687 , BCE in this minibatch:  2.6364758 accuracy:  0.6875
# Batch :  164 / 4687 , BCE in this minibatch:  3.1799707 accuracy:  0.46875
# Batch :  165 / 4687 , BCE in this minibatch:  3.416212 accuracy:  0.59375
# Batch :  166 / 4687 , BCE in this minibatch:  4.0837545 accuracy:  0.59375
# Batch :  167 / 4687 , BCE in this minibatch:  3.2021656 accuracy:  0.5625
# Batch :  168 / 4687 , BCE in this minibatch:  5.220431 accuracy:  0.34375
# Batch :  169 / 4687 , BCE in this minibatch:  2.8386917 accuracy:  0.53125
# Batch :  170 / 4687 , BCE in this minibatch:  3.2009437 accuracy:  0.5625
# Batch :  171 / 4687 , BCE in this minibatch:  4.56727 accuracy:  0.4375
# Batch :  172 / 4687 , BCE in this minibatch:  3.6054235 accuracy:  0.5
# Batch :  173 / 4687 , BCE in this minibatch:  3.605638 accuracy:  0.53125
# Batch :  174 / 4687 , BCE in this minibatch:  3.5878456 accuracy:  0.5
# Batch :  175 / 4687 , BCE in this minibatch:  2.4574661 accuracy:  0.625
# Batch :  176 / 4687 , BCE in this minibatch:  1.7721114 accuracy:  0.65625
# Batch :  177 / 4687 , BCE in this minibatch:  2.483083 accuracy:  0.53125
# Batch :  178 / 4687 , BCE in this minibatch:  2.6777244 accuracy:  0.65625
# Batch :  179 / 4687 , BCE in this minibatch:  3.2046866 accuracy:  0.59375
# Batch :  180 / 4687 , BCE in this minibatch:  2.3657105 accuracy:  0.71875
# Batch :  181 / 4687 , BCE in this minibatch:  5.2897615 accuracy:  0.40625
# Batch :  182 / 4687 , BCE in this minibatch:  2.1949143 accuracy:  0.5625
# Batch :  183 / 4687 , BCE in this minibatch:  3.593457 accuracy:  0.46875
# Batch :  184 / 4687 , BCE in this minibatch:  4.910225 accuracy:  0.375
# Batch :  185 / 4687 , BCE in this minibatch:  3.2630837 accuracy:  0.53125
# Batch :  186 / 4687 , BCE in this minibatch:  3.0992627 accuracy:  0.59375
# Batch :  187 / 4687 , BCE in this minibatch:  3.8665884 accuracy:  0.5
# Batch :  188 / 4687 , BCE in this minibatch:  1.5723325 accuracy:  0.6875
# Batch :  189 / 4687 , BCE in this minibatch:  2.9945533 accuracy:  0.59375
# Batch :  190 / 4687 , BCE in this minibatch:  4.7805424 accuracy:  0.28125
# Batch :  191 / 4687 , BCE in this minibatch:  3.3448048 accuracy:  0.625
# Batch :  192 / 4687 , BCE in this minibatch:  3.723647 accuracy:  0.4375
# Batch :  193 / 4687 , BCE in this minibatch:  3.465045 accuracy:  0.5625
# Batch :  194 / 4687 , BCE in this minibatch:  3.9067671 accuracy:  0.4375
# Batch :  195 / 4687 , BCE in this minibatch:  2.6880145 accuracy:  0.71875
# Batch :  196 / 4687 , BCE in this minibatch:  2.9917963 accuracy:  0.53125
# Batch :  197 / 4687 , BCE in this minibatch:  3.561224 accuracy:  0.5
# Batch :  198 / 4687 , BCE in this minibatch:  4.311671 accuracy:  0.46875
# Batch :  199 / 4687 , BCE in this minibatch:  2.0843778 accuracy:  0.625
# Batch :  200 / 4687 , BCE in this minibatch:  3.1060605 accuracy:  0.5
# Batch :  201 / 4687 , BCE in this minibatch:  4.069497 accuracy:  0.59375
# Batch :  202 / 4687 , BCE in this minibatch:  3.482607 accuracy:  0.5
# Batch :  203 / 4687 , BCE in this minibatch:  3.24571 accuracy:  0.40625
# Batch :  204 / 4687 , BCE in this minibatch:  3.5139608 accuracy:  0.5
# Batch :  205 / 4687 , BCE in this minibatch:  3.9095907 accuracy:  0.4375
# Batch :  206 / 4687 , BCE in this minibatch:  2.7308052 accuracy:  0.5625
# Batch :  207 / 4687 , BCE in this minibatch:  3.9565222 accuracy:  0.53125
# Batch :  208 / 4687 , BCE in this minibatch:  4.8049855 accuracy:  0.46875
# Batch :  209 / 4687 , BCE in this minibatch:  3.8099947 accuracy:  0.53125
# Batch :  210 / 4687 , BCE in this minibatch:  3.6420827 accuracy:  0.65625
# Batch :  211 / 4687 , BCE in this minibatch:  4.805606 accuracy:  0.4375
# Batch :  212 / 4687 , BCE in this minibatch:  4.450038 accuracy:  0.40625
# Batch :  213 / 4687 , BCE in this minibatch:  3.9328246 accuracy:  0.46875
# Batch :  214 / 4687 , BCE in this minibatch:  3.2430365 accuracy:  0.59375
# Batch :  215 / 4687 , BCE in this minibatch:  3.7372754 accuracy:  0.40625
# Batch :  216 / 4687 , BCE in this minibatch:  2.5606751 accuracy:  0.5625
# Batch :  217 / 4687 , BCE in this minibatch:  1.8623784 accuracy:  0.65625
# Batch :  218 / 4687 , BCE in this minibatch:  3.1050992 accuracy:  0.5625
# Batch :  219 / 4687 , BCE in this minibatch:  2.47676 accuracy:  0.71875
# Batch :  220 / 4687 , BCE in this minibatch:  2.7667756 accuracy:  0.625
# Batch :  221 / 4687 , BCE in this minibatch:  2.268805 accuracy:  0.4375
# Batch :  222 / 4687 , BCE in this minibatch:  3.605804 accuracy:  0.5
# Batch :  223 / 4687 , BCE in this minibatch:  4.570902 accuracy:  0.375
# Batch :  224 / 4687 , BCE in this minibatch:  3.0917888 accuracy:  0.625
# Batch :  225 / 4687 , BCE in this minibatch:  3.0104666 accuracy:  0.59375
# Batch :  226 / 4687 , BCE in this minibatch:  4.33119 accuracy:  0.4375
# Batch :  227 / 4687 , BCE in this minibatch:  3.1294217 accuracy:  0.625
# Batch :  228 / 4687 , BCE in this minibatch:  4.3417263 accuracy:  0.46875
# Batch :  229 / 4687 , BCE in this minibatch:  3.9322686 accuracy:  0.4375
# Batch :  230 / 4687 , BCE in this minibatch:  2.513311 accuracy:  0.59375
# Batch :  231 / 4687 , BCE in this minibatch:  2.795333 accuracy:  0.5625
# Batch :  232 / 4687 , BCE in this minibatch:  3.588264 accuracy:  0.4375
# Batch :  233 / 4687 , BCE in this minibatch:  3.0403028 accuracy:  0.59375
# Batch :  234 / 4687 , BCE in this minibatch:  5.4236746 accuracy:  0.375
# Batch :  235 / 4687 , BCE in this minibatch:  3.827609 accuracy:  0.46875
# Batch :  236 / 4687 , BCE in this minibatch:  2.8145652 accuracy:  0.5
# Batch :  237 / 4687 , BCE in this minibatch:  4.3869524 accuracy:  0.53125
# Batch :  238 / 4687 , BCE in this minibatch:  3.4305334 accuracy:  0.65625
# Batch :  239 / 4687 , BCE in this minibatch:  1.9587231 accuracy:  0.6875
# Batch :  240 / 4687 , BCE in this minibatch:  3.5731182 accuracy:  0.46875
# Batch :  241 / 4687 , BCE in this minibatch:  4.393757 accuracy:  0.4375
# Batch :  242 / 4687 , BCE in this minibatch:  3.1142755 accuracy:  0.65625
# Batch :  243 / 4687 , BCE in this minibatch:  3.6355429 accuracy:  0.5
# Batch :  244 / 4687 , BCE in this minibatch:  4.154111 accuracy:  0.5
# Batch :  245 / 4687 , BCE in this minibatch:  2.1872017 accuracy:  0.6875
# Batch :  246 / 4687 , BCE in this minibatch:  4.24092 accuracy:  0.40625
# Batch :  247 / 4687 , BCE in this minibatch:  2.8533635 accuracy:  0.59375
# Batch :  248 / 4687 , BCE in this minibatch:  3.610376 accuracy:  0.5
# Batch :  249 / 4687 , BCE in this minibatch:  3.25108 accuracy:  0.53125
# Batch :  250 / 4687 , BCE in this minibatch:  3.1574867 accuracy:  0.53125
# Batch :  251 / 4687 , BCE in this minibatch:  1.8583133 accuracy:  0.625
# Batch :  252 / 4687 , BCE in this minibatch:  3.3853798 accuracy:  0.53125
# Batch :  253 / 4687 , BCE in this minibatch:  4.176708 accuracy:  0.5625
# Batch :  254 / 4687 , BCE in this minibatch:  2.5912604 accuracy:  0.59375
# Batch :  255 / 4687 , BCE in this minibatch:  4.1371555 accuracy:  0.34375
# Batch :  256 / 4687 , BCE in this minibatch:  2.714167 accuracy:  0.59375
# Batch :  257 / 4687 , BCE in this minibatch:  2.126913 accuracy:  0.625
# Batch :  258 / 4687 , BCE in this minibatch:  3.9169617 accuracy:  0.5
# Batch :  259 / 4687 , BCE in this minibatch:  1.7382512 accuracy:  0.6875
# Batch :  260 / 4687 , BCE in this minibatch:  5.057946 accuracy:  0.46875
# Batch :  261 / 4687 , BCE in this minibatch:  2.124544 accuracy:  0.65625
# Batch :  262 / 4687 , BCE in this minibatch:  2.837555 accuracy:  0.59375
# Batch :  263 / 4687 , BCE in this minibatch:  2.5201445 accuracy:  0.65625
# Batch :  264 / 4687 , BCE in this minibatch:  3.802489 accuracy:  0.5625
# Batch :  265 / 4687 , BCE in this minibatch:  2.5063493 accuracy:  0.65625
# Batch :  266 / 4687 , BCE in this minibatch:  2.7894588 accuracy:  0.5625
# Batch :  267 / 4687 , BCE in this minibatch:  2.8878613 accuracy:  0.5625
# Batch :  268 / 4687 , BCE in this minibatch:  3.8748841 accuracy:  0.46875
# Batch :  269 / 4687 , BCE in this minibatch:  4.2059765 accuracy:  0.53125
# Batch :  270 / 4687 , BCE in this minibatch:  4.969882 accuracy:  0.4375
# Batch :  271 / 4687 , BCE in this minibatch:  3.6016889 accuracy:  0.53125
# Batch :  272 / 4687 , BCE in this minibatch:  3.1897779 accuracy:  0.625
# Batch :  273 / 4687 , BCE in this minibatch:  3.4854465 accuracy:  0.53125
# Batch :  274 / 4687 , BCE in this minibatch:  5.021569 accuracy:  0.46875
# Batch :  275 / 4687 , BCE in this minibatch:  4.3324003 accuracy:  0.5
# Batch :  276 / 4687 , BCE in this minibatch:  3.5812998 accuracy:  0.59375
# Batch :  277 / 4687 , BCE in this minibatch:  3.246627 accuracy:  0.59375
# Batch :  278 / 4687 , BCE in this minibatch:  3.263606 accuracy:  0.6875
# Batch :  279 / 4687 , BCE in this minibatch:  2.930239 accuracy:  0.59375
# Batch :  280 / 4687 , BCE in this minibatch:  2.475937 accuracy:  0.625
# Batch :  281 / 4687 , BCE in this minibatch:  3.7326577 accuracy:  0.4375
# Batch :  282 / 4687 , BCE in this minibatch:  3.436084 accuracy:  0.53125
# Batch :  283 / 4687 , BCE in this minibatch:  5.5370836 accuracy:  0.34375
# Batch :  284 / 4687 , BCE in this minibatch:  2.923979 accuracy:  0.6875
# Batch :  285 / 4687 , BCE in this minibatch:  3.8588758 accuracy:  0.5
# Batch :  286 / 4687 , BCE in this minibatch:  3.6760733 accuracy:  0.53125
# Batch :  287 / 4687 , BCE in this minibatch:  2.5916464 accuracy:  0.65625
# Batch :  288 / 4687 , BCE in this minibatch:  3.1516178 accuracy:  0.53125
# Batch :  289 / 4687 , BCE in this minibatch:  3.4252012 accuracy:  0.5625
# Batch :  290 / 4687 , BCE in this minibatch:  2.5213423 accuracy:  0.65625
# Batch :  291 / 4687 , BCE in this minibatch:  4.3392673 accuracy:  0.5
# Batch :  292 / 4687 , BCE in this minibatch:  2.3987799 accuracy:  0.625
# Batch :  293 / 4687 , BCE in this minibatch:  1.9100599 accuracy:  0.71875
# Batch :  294 / 4687 , BCE in this minibatch:  4.5949926 accuracy:  0.4375
# Batch :  295 / 4687 , BCE in this minibatch:  2.7378864 accuracy:  0.65625
# Batch :  296 / 4687 , BCE in this minibatch:  3.374222 accuracy:  0.5625
# Batch :  297 / 4687 , BCE in this minibatch:  1.7017815 accuracy:  0.78125
# Batch :  298 / 4687 , BCE in this minibatch:  3.3260078 accuracy:  0.5625
# Batch :  299 / 4687 , BCE in this minibatch:  4.1213512 accuracy:  0.5
# Batch :  300 / 4687 , BCE in this minibatch:  3.2037997 accuracy:  0.5625
# Batch :  301 / 4687 , BCE in this minibatch:  3.8730493 accuracy:  0.40625
# Batch :  302 / 4687 , BCE in this minibatch:  1.3008634 accuracy:  0.65625
# Batch :  303 / 4687 , BCE in this minibatch:  3.4750605 accuracy:  0.5625
# Batch :  304 / 4687 , BCE in this minibatch:  4.4036417 accuracy:  0.5625
# Batch :  305 / 4687 , BCE in this minibatch:  3.6665142 accuracy:  0.46875
# Batch :  306 / 4687 , BCE in this minibatch:  1.283931 accuracy:  0.625
# Batch :  307 / 4687 , BCE in this minibatch:  2.6429396 accuracy:  0.59375
# Batch :  308 / 4687 , BCE in this minibatch:  2.5138996 accuracy:  0.625
# Batch :  309 / 4687 , BCE in this minibatch:  1.5336872 accuracy:  0.71875
# Batch :  310 / 4687 , BCE in this minibatch:  3.0321984 accuracy:  0.59375
# Batch :  311 / 4687 , BCE in this minibatch:  3.0961607 accuracy:  0.5625
# Batch :  312 / 4687 , BCE in this minibatch:  4.8214216 accuracy:  0.46875
# Batch :  313 / 4687 , BCE in this minibatch:  1.7971432 accuracy:  0.5625
# Batch :  314 / 4687 , BCE in this minibatch:  3.4084635 accuracy:  0.40625
# Batch :  315 / 4687 , BCE in this minibatch:  3.0722826 accuracy:  0.5625
# Batch :  316 / 4687 , BCE in this minibatch:  4.244346 accuracy:  0.53125
# Batch :  317 / 4687 , BCE in this minibatch:  3.9383392 accuracy:  0.53125
# Batch :  318 / 4687 , BCE in this minibatch:  3.0985758 accuracy:  0.59375
# Batch :  319 / 4687 , BCE in this minibatch:  2.9358978 accuracy:  0.65625
# Batch :  320 / 4687 , BCE in this minibatch:  3.7231102 accuracy:  0.46875
# Batch :  321 / 4687 , BCE in this minibatch:  1.912585 accuracy:  0.65625
# Batch :  322 / 4687 , BCE in this minibatch:  3.0490966 accuracy:  0.59375
# Batch :  323 / 4687 , BCE in this minibatch:  1.97082 accuracy:  0.6875
# Batch :  324 / 4687 , BCE in this minibatch:  2.2354317 accuracy:  0.6875
# Batch :  325 / 4687 , BCE in this minibatch:  5.0230274 accuracy:  0.4375
# Batch :  326 / 4687 , BCE in this minibatch:  4.958473 accuracy:  0.5
# Batch :  327 / 4687 , BCE in this minibatch:  2.8817582 accuracy:  0.53125
# Batch :  328 / 4687 , BCE in this minibatch:  3.9850407 accuracy:  0.5
# Batch :  329 / 4687 , BCE in this minibatch:  2.7583127 accuracy:  0.59375
# Batch :  330 / 4687 , BCE in this minibatch:  2.7960649 accuracy:  0.5625
# Batch :  331 / 4687 , BCE in this minibatch:  1.9488033 accuracy:  0.75
# Batch :  332 / 4687 , BCE in this minibatch:  3.0969796 accuracy:  0.5
# Batch :  333 / 4687 , BCE in this minibatch:  2.3771362 accuracy:  0.625
# Batch :  334 / 4687 , BCE in this minibatch:  3.232186 accuracy:  0.4375
# Batch :  335 / 4687 , BCE in this minibatch:  2.6276093 accuracy:  0.5
# Batch :  336 / 4687 , BCE in this minibatch:  3.198052 accuracy:  0.59375
# Batch :  337 / 4687 , BCE in this minibatch:  3.6158967 accuracy:  0.53125
# Batch :  338 / 4687 , BCE in this minibatch:  2.6590948 accuracy:  0.59375
# Batch :  339 / 4687 , BCE in this minibatch:  2.1887212 accuracy:  0.625
# Batch :  340 / 4687 , BCE in this minibatch:  1.9601939 accuracy:  0.71875
# Batch :  341 / 4687 , BCE in this minibatch:  3.1189442 accuracy:  0.5
# Batch :  342 / 4687 , BCE in this minibatch:  2.8439717 accuracy:  0.5
# Batch :  343 / 4687 , BCE in this minibatch:  3.1315403 accuracy:  0.65625
# Batch :  344 / 4687 , BCE in this minibatch:  3.9477139 accuracy:  0.53125
# Batch :  345 / 4687 , BCE in this minibatch:  3.130621 accuracy:  0.625
# Batch :  346 / 4687 , BCE in this minibatch:  2.258814 accuracy:  0.65625
# Batch :  347 / 4687 , BCE in this minibatch:  3.1213033 accuracy:  0.625
# Batch :  348 / 4687 , BCE in this minibatch:  3.1054635 accuracy:  0.625
# Batch :  349 / 4687 , BCE in this minibatch:  3.2274334 accuracy:  0.625
# Batch :  350 / 4687 , BCE in this minibatch:  3.4988945 accuracy:  0.5
# Batch :  351 / 4687 , BCE in this minibatch:  2.719699 accuracy:  0.5625
# Batch :  352 / 4687 , BCE in this minibatch:  2.4284847 accuracy:  0.6875
# Batch :  353 / 4687 , BCE in this minibatch:  2.8509407 accuracy:  0.625
# Batch :  354 / 4687 , BCE in this minibatch:  1.7149478 accuracy:  0.6875
# Batch :  355 / 4687 , BCE in this minibatch:  2.5097394 accuracy:  0.65625
# Batch :  356 / 4687 , BCE in this minibatch:  2.1492922 accuracy:  0.71875
# Batch :  357 / 4687 , BCE in this minibatch:  3.5317504 accuracy:  0.53125
# Batch :  358 / 4687 , BCE in this minibatch:  2.9121115 accuracy:  0.53125
# Batch :  359 / 4687 , BCE in this minibatch:  1.8438509 accuracy:  0.6875
# Batch :  360 / 4687 , BCE in this minibatch:  2.6165013 accuracy:  0.625
# Batch :  361 / 4687 , BCE in this minibatch:  1.6304328 accuracy:  0.6875
# Batch :  362 / 4687 , BCE in this minibatch:  5.1989765 accuracy:  0.46875
# Batch :  363 / 4687 , BCE in this minibatch:  3.0860097 accuracy:  0.5625
# Batch :  364 / 4687 , BCE in this minibatch:  2.3570452 accuracy:  0.6875
# Batch :  365 / 4687 , BCE in this minibatch:  2.5300713 accuracy:  0.5
# Batch :  366 / 4687 , BCE in this minibatch:  1.8082955 accuracy:  0.6875
# Batch :  367 / 4687 , BCE in this minibatch:  3.4909396 accuracy:  0.625
# Batch :  368 / 4687 , BCE in this minibatch:  1.2648377 accuracy:  0.78125
# Batch :  369 / 4687 , BCE in this minibatch:  6.139581 accuracy:  0.34375
# Batch :  370 / 4687 , BCE in this minibatch:  2.0631123 accuracy:  0.6875
# Batch :  371 / 4687 , BCE in this minibatch:  3.006169 accuracy:  0.5625
# Batch :  372 / 4687 , BCE in this minibatch:  3.5943618 accuracy:  0.4375
# Batch :  373 / 4687 , BCE in this minibatch:  3.59508 accuracy:  0.65625
# Batch :  374 / 4687 , BCE in this minibatch:  3.735033 accuracy:  0.53125
# Batch :  375 / 4687 , BCE in this minibatch:  2.9467196 accuracy:  0.59375
# Batch :  376 / 4687 , BCE in this minibatch:  3.0744717 accuracy:  0.53125
# Batch :  377 / 4687 , BCE in this minibatch:  2.727629 accuracy:  0.625
# Batch :  378 / 4687 , BCE in this minibatch:  3.0493026 accuracy:  0.59375
# Batch :  379 / 4687 , BCE in this minibatch:  1.60994 accuracy:  0.65625
# Batch :  380 / 4687 , BCE in this minibatch:  2.3406563 accuracy:  0.5625
# Batch :  381 / 4687 , BCE in this minibatch:  2.6633615 accuracy:  0.625
# Batch :  382 / 4687 , BCE in this minibatch:  2.4580145 accuracy:  0.65625
# Batch :  383 / 4687 , BCE in this minibatch:  3.538752 accuracy:  0.53125
# Batch :  384 / 4687 , BCE in this minibatch:  3.3365016 accuracy:  0.4375
# Batch :  385 / 4687 , BCE in this minibatch:  2.9311757 accuracy:  0.59375
# Batch :  386 / 4687 , BCE in this minibatch:  3.0411217 accuracy:  0.5625
# Batch :  387 / 4687 , BCE in this minibatch:  3.6358528 accuracy:  0.5625
# Batch :  388 / 4687 , BCE in this minibatch:  3.51595 accuracy:  0.59375
# Batch :  389 / 4687 , BCE in this minibatch:  2.332105 accuracy:  0.65625
# Batch :  390 / 4687 , BCE in this minibatch:  3.169903 accuracy:  0.59375
# Batch :  391 / 4687 , BCE in this minibatch:  2.8078747 accuracy:  0.53125
# Batch :  392 / 4687 , BCE in this minibatch:  2.8834076 accuracy:  0.53125
# Batch :  393 / 4687 , BCE in this minibatch:  4.1140037 accuracy:  0.53125
# Batch :  394 / 4687 , BCE in this minibatch:  3.5132563 accuracy:  0.625
# Batch :  395 / 4687 , BCE in this minibatch:  2.5854292 accuracy:  0.6875
# Batch :  396 / 4687 , BCE in this minibatch:  2.424176 accuracy:  0.625
# Batch :  397 / 4687 , BCE in this minibatch:  2.7715833 accuracy:  0.6875
# Batch :  398 / 4687 , BCE in this minibatch:  1.5625798 accuracy:  0.6875
# Batch :  399 / 4687 , BCE in this minibatch:  2.3750265 accuracy:  0.6875
# Batch :  400 / 4687 , BCE in this minibatch:  3.2456894 accuracy:  0.53125
# Batch :  401 / 4687 , BCE in this minibatch:  3.2010984 accuracy:  0.625
# Batch :  402 / 4687 , BCE in this minibatch:  4.287965 accuracy:  0.4375
# Batch :  403 / 4687 , BCE in this minibatch:  2.710747 accuracy:  0.46875
# Batch :  404 / 4687 , BCE in this minibatch:  2.1654418 accuracy:  0.625
# Batch :  405 / 4687 , BCE in this minibatch:  3.8295486 accuracy:  0.53125
# Batch :  406 / 4687 , BCE in this minibatch:  2.6860461 accuracy:  0.6875
# Batch :  407 / 4687 , BCE in this minibatch:  1.7776017 accuracy:  0.6875
# Batch :  408 / 4687 , BCE in this minibatch:  3.1330256 accuracy:  0.59375
# Batch :  409 / 4687 , BCE in this minibatch:  4.0336957 accuracy:  0.375
# Batch :  410 / 4687 , BCE in this minibatch:  1.4246519 accuracy:  0.71875
# Batch :  411 / 4687 , BCE in this minibatch:  1.6810035 accuracy:  0.65625
# Batch :  412 / 4687 , BCE in this minibatch:  3.9143202 accuracy:  0.53125
# Batch :  413 / 4687 , BCE in this minibatch:  2.988936 accuracy:  0.59375
# Batch :  414 / 4687 , BCE in this minibatch:  2.3165538 accuracy:  0.6875
# Batch :  415 / 4687 , BCE in this minibatch:  2.4425945 accuracy:  0.5625
# Batch :  416 / 4687 , BCE in this minibatch:  2.805779 accuracy:  0.59375
# Batch :  417 / 4687 , BCE in this minibatch:  3.6026604 accuracy:  0.40625
# Batch :  418 / 4687 , BCE in this minibatch:  3.3654766 accuracy:  0.59375
# Batch :  419 / 4687 , BCE in this minibatch:  1.9212306 accuracy:  0.6875
# Batch :  420 / 4687 , BCE in this minibatch:  2.8275342 accuracy:  0.59375
# Batch :  421 / 4687 , BCE in this minibatch:  2.146555 accuracy:  0.59375
# Batch :  422 / 4687 , BCE in this minibatch:  2.2910395 accuracy:  0.59375
# Batch :  423 / 4687 , BCE in this minibatch:  2.6123238 accuracy:  0.59375
# Batch :  424 / 4687 , BCE in this minibatch:  2.362157 accuracy:  0.59375
# Batch :  425 / 4687 , BCE in this minibatch:  3.7223692 accuracy:  0.40625
# Batch :  426 / 4687 , BCE in this minibatch:  4.194562 accuracy:  0.46875
# Batch :  427 / 4687 , BCE in this minibatch:  4.1072226 accuracy:  0.5
# Batch :  428 / 4687 , BCE in this minibatch:  1.8246026 accuracy:  0.59375
# Batch :  429 / 4687 , BCE in this minibatch:  2.4086506 accuracy:  0.59375
# Batch :  430 / 4687 , BCE in this minibatch:  3.5204988 accuracy:  0.53125
# Batch :  431 / 4687 , BCE in this minibatch:  5.159413 accuracy:  0.4375
# Batch :  432 / 4687 , BCE in this minibatch:  2.8695033 accuracy:  0.625
# Batch :  433 / 4687 , BCE in this minibatch:  2.4127731 accuracy:  0.71875
# Batch :  434 / 4687 , BCE in this minibatch:  2.742722 accuracy:  0.65625
# Batch :  435 / 4687 , BCE in this minibatch:  3.8994417 accuracy:  0.46875
# Batch :  436 / 4687 , BCE in this minibatch:  3.8795576 accuracy:  0.46875
# Batch :  437 / 4687 , BCE in this minibatch:  2.5467157 accuracy:  0.625
# Batch :  438 / 4687 , BCE in this minibatch:  3.712421 accuracy:  0.53125
# Batch :  439 / 4687 , BCE in this minibatch:  2.8585029 accuracy:  0.625
# Batch :  440 / 4687 , BCE in this minibatch:  1.5711613 accuracy:  0.6875
# Batch :  441 / 4687 , BCE in this minibatch:  2.130042 accuracy:  0.6875
# Batch :  442 / 4687 , BCE in this minibatch:  3.9950361 accuracy:  0.5
# Batch :  443 / 4687 , BCE in this minibatch:  2.11873 accuracy:  0.65625
# Batch :  444 / 4687 , BCE in this minibatch:  2.7471645 accuracy:  0.5625
# Batch :  445 / 4687 , BCE in this minibatch:  3.587098 accuracy:  0.4375
# Batch :  446 / 4687 , BCE in this minibatch:  2.763801 accuracy:  0.53125
# Batch :  447 / 4687 , BCE in this minibatch:  2.5648034 accuracy:  0.6875
# Batch :  448 / 4687 , BCE in this minibatch:  4.5404453 accuracy:  0.5625
# Batch :  449 / 4687 , BCE in this minibatch:  4.2386684 accuracy:  0.53125
# Batch :  450 / 4687 , BCE in this minibatch:  2.288494 accuracy:  0.65625
# Batch :  451 / 4687 , BCE in this minibatch:  2.9405856 accuracy:  0.65625
# Batch :  452 / 4687 , BCE in this minibatch:  1.5915872 accuracy:  0.625
# Batch :  453 / 4687 , BCE in this minibatch:  4.7144413 accuracy:  0.46875
# Batch :  454 / 4687 , BCE in this minibatch:  2.073574 accuracy:  0.6875
# Batch :  455 / 4687 , BCE in this minibatch:  1.7006353 accuracy:  0.46875
# Batch :  456 / 4687 , BCE in this minibatch:  4.20088 accuracy:  0.53125
# Batch :  457 / 4687 , BCE in this minibatch:  1.9439278 accuracy:  0.6875
# Batch :  458 / 4687 , BCE in this minibatch:  3.9716954 accuracy:  0.4375
# Batch :  459 / 4687 , BCE in this minibatch:  4.136466 accuracy:  0.5
# Batch :  460 / 4687 , BCE in this minibatch:  2.6630158 accuracy:  0.59375
# Batch :  461 / 4687 , BCE in this minibatch:  3.7311454 accuracy:  0.5625
# Batch :  462 / 4687 , BCE in this minibatch:  2.6146843 accuracy:  0.5625
# Batch :  463 / 4687 , BCE in this minibatch:  2.60437 accuracy:  0.6875
# Batch :  464 / 4687 , BCE in this minibatch:  3.2538362 accuracy:  0.53125
# Batch :  465 / 4687 , BCE in this minibatch:  3.3571134 accuracy:  0.53125
# Batch :  466 / 4687 , BCE in this minibatch:  3.4272602 accuracy:  0.53125
# Batch :  467 / 4687 , BCE in this minibatch:  3.952362 accuracy:  0.46875
# Batch :  468 / 4687 , BCE in this minibatch:  4.2154493 accuracy:  0.5
# Batch :  469 / 4687 , BCE in this minibatch:  4.407466 accuracy:  0.5625
# Batch :  470 / 4687 , BCE in this minibatch:  2.8889732 accuracy:  0.53125
# Batch :  471 / 4687 , BCE in this minibatch:  3.0312958 accuracy:  0.5625
# Batch :  472 / 4687 , BCE in this minibatch:  3.0660224 accuracy:  0.65625
# Batch :  473 / 4687 , BCE in this minibatch:  1.4932098 accuracy:  0.71875
# Batch :  474 / 4687 , BCE in this minibatch:  3.0392761 accuracy:  0.5
# Batch :  475 / 4687 , BCE in this minibatch:  2.7720861 accuracy:  0.59375
# Batch :  476 / 4687 , BCE in this minibatch:  2.3404832 accuracy:  0.71875
# Batch :  477 / 4687 , BCE in this minibatch:  2.1533892 accuracy:  0.625
# Batch :  478 / 4687 , BCE in this minibatch:  5.011796 accuracy:  0.375
# Batch :  479 / 4687 , BCE in this minibatch:  3.5680327 accuracy:  0.5625
# Batch :  480 / 4687 , BCE in this minibatch:  2.8266354 accuracy:  0.5625
# Batch :  481 / 4687 , BCE in this minibatch:  3.206534 accuracy:  0.5625
# Batch :  482 / 4687 , BCE in this minibatch:  2.5743127 accuracy:  0.53125
# Batch :  483 / 4687 , BCE in this minibatch:  2.5087569 accuracy:  0.5625
# Batch :  484 / 4687 , BCE in this minibatch:  3.4245882 accuracy:  0.65625
# Batch :  485 / 4687 , BCE in this minibatch:  3.66862 accuracy:  0.5625
# Batch :  486 / 4687 , BCE in this minibatch:  2.9759452 accuracy:  0.625
# Batch :  487 / 4687 , BCE in this minibatch:  3.945196 accuracy:  0.5
# Batch :  488 / 4687 , BCE in this minibatch:  3.1229877 accuracy:  0.5
# Batch :  489 / 4687 , BCE in this minibatch:  2.5319939 accuracy:  0.5625
# Batch :  490 / 4687 , BCE in this minibatch:  4.3454685 accuracy:  0.53125
# Batch :  491 / 4687 , BCE in this minibatch:  2.5734649 accuracy:  0.625
# Batch :  492 / 4687 , BCE in this minibatch:  2.1913195 accuracy:  0.625
# Batch :  493 / 4687 , BCE in this minibatch:  3.5384803 accuracy:  0.5625
# Batch :  494 / 4687 , BCE in this minibatch:  1.2536858 accuracy:  0.71875
# Batch :  495 / 4687 , BCE in this minibatch:  3.3327594 accuracy:  0.46875
# Batch :  496 / 4687 , BCE in this minibatch:  1.8370414 accuracy:  0.65625
# Batch :  497 / 4687 , BCE in this minibatch:  3.9650364 accuracy:  0.53125
# Batch :  498 / 4687 , BCE in this minibatch:  2.3995585 accuracy:  0.6875
# Batch :  499 / 4687 , BCE in this minibatch:  2.8221068 accuracy:  0.59375
# Batch :  500 / 4687 , BCE in this minibatch:  1.8938504 accuracy:  0.625
# Batch :  501 / 4687 , BCE in this minibatch:  3.6034007 accuracy:  0.46875
# Batch :  502 / 4687 , BCE in this minibatch:  2.8581705 accuracy:  0.6875
# Batch :  503 / 4687 , BCE in this minibatch:  3.00145 accuracy:  0.5625
# Batch :  504 / 4687 , BCE in this minibatch:  1.3107951 accuracy:  0.65625
# Batch :  505 / 4687 , BCE in this minibatch:  2.6437116 accuracy:  0.65625
# Batch :  506 / 4687 , BCE in this minibatch:  3.6559556 accuracy:  0.53125
# Batch :  507 / 4687 , BCE in this minibatch:  3.1569226 accuracy:  0.5625
# Batch :  508 / 4687 , BCE in this minibatch:  2.1312318 accuracy:  0.5625
# Batch :  509 / 4687 , BCE in this minibatch:  0.9032923 accuracy:  0.71875
# Batch :  510 / 4687 , BCE in this minibatch:  2.298232 accuracy:  0.5625
# Batch :  511 / 4687 , BCE in this minibatch:  3.6901596 accuracy:  0.53125
# Batch :  512 / 4687 , BCE in this minibatch:  2.662518 accuracy:  0.71875
# Batch :  513 / 4687 , BCE in this minibatch:  4.914951 accuracy:  0.53125
# Batch :  514 / 4687 , BCE in this minibatch:  3.4035397 accuracy:  0.5625
# Batch :  515 / 4687 , BCE in this minibatch:  2.8452969 accuracy:  0.65625
# Batch :  516 / 4687 , BCE in this minibatch:  4.8792315 accuracy:  0.40625
# Batch :  517 / 4687 , BCE in this minibatch:  2.573543 accuracy:  0.6875
# Batch :  518 / 4687 , BCE in this minibatch:  3.3554382 accuracy:  0.59375
# Batch :  519 / 4687 , BCE in this minibatch:  2.3498516 accuracy:  0.53125
# Batch :  520 / 4687 , BCE in this minibatch:  2.4156966 accuracy:  0.59375
# Batch :  521 / 4687 , BCE in this minibatch:  1.9732171 accuracy:  0.65625
# Batch :  522 / 4687 , BCE in this minibatch:  2.8376603 accuracy:  0.5625
# Batch :  523 / 4687 , BCE in this minibatch:  2.2918372 accuracy:  0.53125
# Batch :  524 / 4687 , BCE in this minibatch:  3.6887147 accuracy:  0.5625
# Batch :  525 / 4687 , BCE in this minibatch:  2.8844109 accuracy:  0.5
# Batch :  526 / 4687 , BCE in this minibatch:  4.6205716 accuracy:  0.5625
# Batch :  527 / 4687 , BCE in this minibatch:  3.0428216 accuracy:  0.53125
# Batch :  528 / 4687 , BCE in this minibatch:  2.2668166 accuracy:  0.65625
# Batch :  529 / 4687 , BCE in this minibatch:  2.1066809 accuracy:  0.65625
# Batch :  530 / 4687 , BCE in this minibatch:  3.7899437 accuracy:  0.5625
# Batch :  531 / 4687 , BCE in this minibatch:  2.6343684 accuracy:  0.53125
# Batch :  532 / 4687 , BCE in this minibatch:  2.4566255 accuracy:  0.625
# Batch :  533 / 4687 , BCE in this minibatch:  3.0486274 accuracy:  0.5625
# Batch :  534 / 4687 , BCE in this minibatch:  2.6482377 accuracy:  0.59375
# Batch :  535 / 4687 , BCE in this minibatch:  2.4068563 accuracy:  0.6875
# Batch :  536 / 4687 , BCE in this minibatch:  4.2793064 accuracy:  0.5
# Batch :  537 / 4687 , BCE in this minibatch:  3.560916 accuracy:  0.625
# Batch :  538 / 4687 , BCE in this minibatch:  2.915442 accuracy:  0.59375
# Batch :  539 / 4687 , BCE in this minibatch:  2.1797748 accuracy:  0.6875
# Batch :  540 / 4687 , BCE in this minibatch:  3.2219512 accuracy:  0.5625
# Batch :  541 / 4687 , BCE in this minibatch:  3.9494748 accuracy:  0.5625
# Batch :  542 / 4687 , BCE in this minibatch:  2.6914644 accuracy:  0.59375
# Batch :  543 / 4687 , BCE in this minibatch:  3.4033298 accuracy:  0.59375
# Batch :  544 / 4687 , BCE in this minibatch:  1.8796217 accuracy:  0.78125
# Batch :  545 / 4687 , BCE in this minibatch:  1.4326552 accuracy:  0.71875
# Batch :  546 / 4687 , BCE in this minibatch:  4.0212393 accuracy:  0.46875
# Batch :  547 / 4687 , BCE in this minibatch:  3.1769934 accuracy:  0.625
# Batch :  548 / 4687 , BCE in this minibatch:  2.5064135 accuracy:  0.625
# Batch :  549 / 4687 , BCE in this minibatch:  3.8397737 accuracy:  0.53125
# Batch :  550 / 4687 , BCE in this minibatch:  2.5252175 accuracy:  0.625
# Batch :  551 / 4687 , BCE in this minibatch:  2.1521084 accuracy:  0.625
# Batch :  552 / 4687 , BCE in this minibatch:  2.8526263 accuracy:  0.625
# Batch :  553 / 4687 , BCE in this minibatch:  2.2980878 accuracy:  0.6875
# Batch :  554 / 4687 , BCE in this minibatch:  2.7768488 accuracy:  0.625
# Batch :  555 / 4687 , BCE in this minibatch:  4.6946626 accuracy:  0.4375
# Batch :  556 / 4687 , BCE in this minibatch:  3.0115504 accuracy:  0.71875
# Batch :  557 / 4687 , BCE in this minibatch:  2.2576785 accuracy:  0.59375
# Batch :  558 / 4687 , BCE in this minibatch:  3.8676257 accuracy:  0.5625
# Batch :  559 / 4687 , BCE in this minibatch:  3.194884 accuracy:  0.5
# Batch :  560 / 4687 , BCE in this minibatch:  2.4738388 accuracy:  0.59375
# Batch :  561 / 4687 , BCE in this minibatch:  1.8569912 accuracy:  0.65625
# Batch :  562 / 4687 , BCE in this minibatch:  2.4090307 accuracy:  0.625
# Batch :  563 / 4687 , BCE in this minibatch:  2.9611018 accuracy:  0.65625
# Batch :  564 / 4687 , BCE in this minibatch:  1.7448156 accuracy:  0.65625
# Batch :  565 / 4687 , BCE in this minibatch:  2.2631335 accuracy:  0.71875
# Batch :  566 / 4687 , BCE in this minibatch:  2.1235876 accuracy:  0.6875
# Batch :  567 / 4687 , BCE in this minibatch:  2.9987202 accuracy:  0.65625
# Batch :  568 / 4687 , BCE in this minibatch:  1.2462776 accuracy:  0.8125
# Batch :  569 / 4687 , BCE in this minibatch:  1.9492855 accuracy:  0.71875
# Batch :  570 / 4687 , BCE in this minibatch:  1.1673462 accuracy:  0.6875
# Batch :  571 / 4687 , BCE in this minibatch:  4.2984843 accuracy:  0.5
# Batch :  572 / 4687 , BCE in this minibatch:  2.124094 accuracy:  0.59375
# Batch :  573 / 4687 , BCE in this minibatch:  3.3106375 accuracy:  0.59375
# Batch :  574 / 4687 , BCE in this minibatch:  3.93161 accuracy:  0.5
# Batch :  575 / 4687 , BCE in this minibatch:  3.738442 accuracy:  0.53125
# Batch :  576 / 4687 , BCE in this minibatch:  2.606538 accuracy:  0.5625
# Batch :  577 / 4687 , BCE in this minibatch:  4.3546324 accuracy:  0.40625
# Batch :  578 / 4687 , BCE in this minibatch:  2.8923452 accuracy:  0.59375
# Batch :  579 / 4687 , BCE in this minibatch:  2.4595604 accuracy:  0.5625
# Batch :  580 / 4687 , BCE in this minibatch:  2.2163672 accuracy:  0.6875
# Batch :  581 / 4687 , BCE in this minibatch:  3.7348444 accuracy:  0.5
# Batch :  582 / 4687 , BCE in this minibatch:  3.006031 accuracy:  0.6875
# Batch :  583 / 4687 , BCE in this minibatch:  1.4980415 accuracy:  0.71875
# Batch :  584 / 4687 , BCE in this minibatch:  3.3267703 accuracy:  0.5625
# Batch :  585 / 4687 , BCE in this minibatch:  4.419029 accuracy:  0.4375
# Batch :  586 / 4687 , BCE in this minibatch:  2.0992372 accuracy:  0.75
# Batch :  587 / 4687 , BCE in this minibatch:  2.042373 accuracy:  0.75
# Batch :  588 / 4687 , BCE in this minibatch:  3.7596974 accuracy:  0.5625
# Batch :  589 / 4687 , BCE in this minibatch:  3.4205866 accuracy:  0.5
# Batch :  590 / 4687 , BCE in this minibatch:  1.8421092 accuracy:  0.625
# Batch :  591 / 4687 , BCE in this minibatch:  2.551053 accuracy:  0.53125
# Batch :  592 / 4687 , BCE in this minibatch:  3.9456408 accuracy:  0.46875
# Batch :  593 / 4687 , BCE in this minibatch:  2.6500263 accuracy:  0.625
# Batch :  594 / 4687 , BCE in this minibatch:  1.9385885 accuracy:  0.6875
# Batch :  595 / 4687 , BCE in this minibatch:  2.4265592 accuracy:  0.6875
# Batch :  596 / 4687 , BCE in this minibatch:  1.7403518 accuracy:  0.71875
# Batch :  597 / 4687 , BCE in this minibatch:  3.0470784 accuracy:  0.5625
# Batch :  598 / 4687 , BCE in this minibatch:  2.149705 accuracy:  0.53125
# Batch :  599 / 4687 , BCE in this minibatch:  2.8174243 accuracy:  0.625
# Batch :  600 / 4687 , BCE in this minibatch:  2.3220422 accuracy:  0.6875
# Batch :  601 / 4687 , BCE in this minibatch:  3.0319881 accuracy:  0.59375
# Batch :  602 / 4687 , BCE in this minibatch:  1.8182902 accuracy:  0.6875
# Batch :  603 / 4687 , BCE in this minibatch:  3.3972588 accuracy:  0.5625
# Batch :  604 / 4687 , BCE in this minibatch:  3.657455 accuracy:  0.625
# Batch :  605 / 4687 , BCE in this minibatch:  3.0555446 accuracy:  0.6875
# Batch :  606 / 4687 , BCE in this minibatch:  3.2099247 accuracy:  0.625
# Batch :  607 / 4687 , BCE in this minibatch:  1.873615 accuracy:  0.78125
# Batch :  608 / 4687 , BCE in this minibatch:  2.82987 accuracy:  0.6875
# Batch :  609 / 4687 , BCE in this minibatch:  3.5448928 accuracy:  0.5625
# Batch :  610 / 4687 , BCE in this minibatch:  2.2296038 accuracy:  0.625
# Batch :  611 / 4687 , BCE in this minibatch:  3.826594 accuracy:  0.40625
# Batch :  612 / 4687 , BCE in this minibatch:  2.0488691 accuracy:  0.6875
# Batch :  613 / 4687 , BCE in this minibatch:  3.2344394 accuracy:  0.5625
# Batch :  614 / 4687 , BCE in this minibatch:  2.6154895 accuracy:  0.5625
# Batch :  615 / 4687 , BCE in this minibatch:  2.448965 accuracy:  0.5
# Batch :  616 / 4687 , BCE in this minibatch:  2.997748 accuracy:  0.59375
# Batch :  617 / 4687 , BCE in this minibatch:  2.404306 accuracy:  0.65625
# Batch :  618 / 4687 , BCE in this minibatch:  2.601941 accuracy:  0.625
# Batch :  619 / 4687 , BCE in this minibatch:  2.5170817 accuracy:  0.65625
# Batch :  620 / 4687 , BCE in this minibatch:  4.1053095 accuracy:  0.4375
# Batch :  621 / 4687 , BCE in this minibatch:  3.4007387 accuracy:  0.46875
# Batch :  622 / 4687 , BCE in this minibatch:  3.634762 accuracy:  0.625
# Batch :  623 / 4687 , BCE in this minibatch:  3.480094 accuracy:  0.625
# Batch :  624 / 4687 , BCE in this minibatch:  2.2498395 accuracy:  0.59375
# Batch :  625 / 4687 , BCE in this minibatch:  3.2213888 accuracy:  0.6875
# Batch :  626 / 4687 , BCE in this minibatch:  1.6628485 accuracy:  0.78125
# Batch :  627 / 4687 , BCE in this minibatch:  2.9886568 accuracy:  0.59375
# Batch :  628 / 4687 , BCE in this minibatch:  1.6900558 accuracy:  0.65625
# Batch :  629 / 4687 , BCE in this minibatch:  2.20054 accuracy:  0.71875
# Batch :  630 / 4687 , BCE in this minibatch:  3.8751297 accuracy:  0.5625
# Batch :  631 / 4687 , BCE in this minibatch:  3.7792377 accuracy:  0.4375
# Batch :  632 / 4687 , BCE in this minibatch:  1.4443271 accuracy:  0.84375
# Batch :  633 / 4687 , BCE in this minibatch:  2.6412911 accuracy:  0.625
# Batch :  634 / 4687 , BCE in this minibatch:  3.0821674 accuracy:  0.5
# Batch :  635 / 4687 , BCE in this minibatch:  4.9573593 accuracy:  0.4375
# Batch :  636 / 4687 , BCE in this minibatch:  3.9100175 accuracy:  0.53125
# Batch :  637 / 4687 , BCE in this minibatch:  1.611031 accuracy:  0.625
# Batch :  638 / 4687 , BCE in this minibatch:  2.2244024 accuracy:  0.625
# Batch :  639 / 4687 , BCE in this minibatch:  3.5773847 accuracy:  0.5
# Batch :  640 / 4687 , BCE in this minibatch:  3.5523243 accuracy:  0.59375
# Batch :  641 / 4687 , BCE in this minibatch:  1.6122694 accuracy:  0.75
# Batch :  642 / 4687 , BCE in this minibatch:  1.9819269 accuracy:  0.65625
# Batch :  643 / 4687 , BCE in this minibatch:  3.0222824 accuracy:  0.59375
# Batch :  644 / 4687 , BCE in this minibatch:  2.6595588 accuracy:  0.59375
# Batch :  645 / 4687 , BCE in this minibatch:  2.5867076 accuracy:  0.65625
# Batch :  646 / 4687 , BCE in this minibatch:  3.0999863 accuracy:  0.5
# Batch :  647 / 4687 , BCE in this minibatch:  2.5536494 accuracy:  0.59375
# Batch :  648 / 4687 , BCE in this minibatch:  2.6263466 accuracy:  0.5
# Batch :  649 / 4687 , BCE in this minibatch:  2.8761268 accuracy:  0.5625
# Batch :  650 / 4687 , BCE in this minibatch:  2.279684 accuracy:  0.59375
# Batch :  651 / 4687 , BCE in this minibatch:  2.4195938 accuracy:  0.6875
# Batch :  652 / 4687 , BCE in this minibatch:  1.5184491 accuracy:  0.625
# ...
# Batch :  2664 / 4687 , BCE in this minibatch:  2.1195202 accuracy:  0.6875
# Batch :  2665 / 4687 , BCE in this minibatch:  1.6958936 accuracy:  0.625
# Batch :  2666 / 4687 , BCE in this minibatch:  1.5993848 accuracy:  0.71875
# Batch :  2667 / 4687 , BCE in this minibatch:  1.643423 accuracy:  0.75
# Batch :  2668 / 4687 , BCE in this minibatch:  1.1656774 accuracy:  0.71875
# Batch :  2669 / 4687 , BCE in this minibatch:  1.4502468 accuracy:  0.71875
# Batch :  2670 / 4687 , BCE in this minibatch:  1.0701077 accuracy:  0.6875
# Batch :  2671 / 4687 , BCE in this minibatch:  1.8508732 accuracy:  0.8125
# Batch :  2672 / 4687 , BCE in this minibatch:  2.8789067 accuracy:  0.625
# Batch :  2673 / 4687 , BCE in this minibatch:  1.2525113 accuracy:  0.84375
# Batch :  2674 / 4687 , BCE in this minibatch:  1.4056703 accuracy:  0.75
# Batch :  2675 / 4687 , BCE in this minibatch:  1.1927688 accuracy:  0.84375
# Batch :  2676 / 4687 , BCE in this minibatch:  1.6271418 accuracy:  0.78125
# Batch :  2677 / 4687 , BCE in this minibatch:  1.1170948 accuracy:  0.71875
# Batch :  2678 / 4687 , BCE in this minibatch:  1.7781541 accuracy:  0.6875
# Batch :  2679 / 4687 , BCE in this minibatch:  0.88916117 accuracy:  0.75
# Batch :  2680 / 4687 , BCE in this minibatch:  0.850067 accuracy:  0.6875
# Batch :  2681 / 4687 , BCE in this minibatch:  1.7419306 accuracy:  0.6875
# Batch :  2682 / 4687 , BCE in this minibatch:  2.056507 accuracy:  0.78125
# Batch :  2683 / 4687 , BCE in this minibatch:  1.349668 accuracy:  0.75
# Batch :  2684 / 4687 , BCE in this minibatch:  0.886287 accuracy:  0.875
# Batch :  2685 / 4687 , BCE in this minibatch:  1.6987977 accuracy:  0.78125
# Batch :  2686 / 4687 , BCE in this minibatch:  1.3339593 accuracy:  0.6875
# Batch :  2687 / 4687 , BCE in this minibatch:  2.1042542 accuracy:  0.65625
# Batch :  2688 / 4687 , BCE in this minibatch:  0.8671956 accuracy:  0.875
# Batch :  2689 / 4687 , BCE in this minibatch:  1.3931501 accuracy:  0.71875
# Batch :  2690 / 4687 , BCE in this minibatch:  1.1832957 accuracy:  0.75
# Batch :  2691 / 4687 , BCE in this minibatch:  1.8597288 accuracy:  0.71875
# Batch :  2692 / 4687 , BCE in this minibatch:  1.0915236 accuracy:  0.8125
# Batch :  2693 / 4687 , BCE in this minibatch:  1.1140835 accuracy:  0.71875
# Batch :  2694 / 4687 , BCE in this minibatch:  1.1968076 accuracy:  0.78125
# Batch :  2695 / 4687 , BCE in this minibatch:  1.0647932 accuracy:  0.75
# Batch :  2696 / 4687 , BCE in this minibatch:  1.1850685 accuracy:  0.84375
# Batch :  2697 / 4687 , BCE in this minibatch:  1.2571537 accuracy:  0.65625
# Batch :  2698 / 4687 , BCE in this minibatch:  1.343112 accuracy:  0.8125
# Batch :  2699 / 4687 , BCE in this minibatch:  1.3388343 accuracy:  0.8125
# Batch :  2700 / 4687 , BCE in this minibatch:  1.7918379 accuracy:  0.71875
# Batch :  2701 / 4687 , BCE in this minibatch:  1.623857 accuracy:  0.6875
# Batch :  2702 / 4687 , BCE in this minibatch:  2.0136971 accuracy:  0.71875
# Batch :  2703 / 4687 , BCE in this minibatch:  1.1706793 accuracy:  0.71875
# Batch :  2704 / 4687 , BCE in this minibatch:  1.9688051 accuracy:  0.6875
# Batch :  2705 / 4687 , BCE in this minibatch:  2.2873304 accuracy:  0.71875
# Batch :  2706 / 4687 , BCE in this minibatch:  1.6041951 accuracy:  0.75
# Batch :  2707 / 4687 , BCE in this minibatch:  0.7325527 accuracy:  0.75
# Batch :  2708 / 4687 , BCE in this minibatch:  1.3731976 accuracy:  0.75
# Batch :  2709 / 4687 , BCE in this minibatch:  1.3425555 accuracy:  0.78125
# Batch :  2710 / 4687 , BCE in this minibatch:  1.0933402 accuracy:  0.78125
# Batch :  2711 / 4687 , BCE in this minibatch:  1.6756988 accuracy:  0.75
# Batch :  2712 / 4687 , BCE in this minibatch:  1.8714235 accuracy:  0.65625
# Batch :  2713 / 4687 , BCE in this minibatch:  0.77355635 accuracy:  0.8125
# Batch :  2714 / 4687 , BCE in this minibatch:  1.3498168 accuracy:  0.71875
# Batch :  2715 / 4687 , BCE in this minibatch:  0.86917996 accuracy:  0.78125
# Batch :  2716 / 4687 , BCE in this minibatch:  1.527585 accuracy:  0.65625
# Batch :  2717 / 4687 , BCE in this minibatch:  1.1117048 accuracy:  0.875
# Batch :  2718 / 4687 , BCE in this minibatch:  2.1963565 accuracy:  0.65625
# Batch :  2719 / 4687 , BCE in this minibatch:  1.3550488 accuracy:  0.84375
# Batch :  2720 / 4687 , BCE in this minibatch:  1.6459508 accuracy:  0.75
# Batch :  2721 / 4687 , BCE in this minibatch:  0.89899945 accuracy:  0.78125
# Batch :  2722 / 4687 , BCE in this minibatch:  2.8100872 accuracy:  0.71875
# Batch :  2723 / 4687 , BCE in this minibatch:  0.29381874 accuracy:  0.9375
# Batch :  2724 / 4687 , BCE in this minibatch:  0.26036867 accuracy:  0.875
# Batch :  2725 / 4687 , BCE in this minibatch:  1.6912571 accuracy:  0.84375
# Batch :  2726 / 4687 , BCE in this minibatch:  1.8054466 accuracy:  0.65625
# Batch :  2727 / 4687 , BCE in this minibatch:  2.47608 accuracy:  0.6875
# Batch :  2728 / 4687 , BCE in this minibatch:  0.9629654 accuracy:  0.875
# Batch :  2729 / 4687 , BCE in this minibatch:  2.9643054 accuracy:  0.5625
# Batch :  2730 / 4687 , BCE in this minibatch:  1.1839916 accuracy:  0.75
# Batch :  2731 / 4687 , BCE in this minibatch:  2.1240563 accuracy:  0.75
# Batch :  2732 / 4687 , BCE in this minibatch:  1.8404781 accuracy:  0.65625
# Batch :  2733 / 4687 , BCE in this minibatch:  1.4114833 accuracy:  0.6875
# Batch :  2734 / 4687 , BCE in this minibatch:  1.8643057 accuracy:  0.78125
# Batch :  2735 / 4687 , BCE in this minibatch:  0.82002383 accuracy:  0.84375
# Batch :  2736 / 4687 , BCE in this minibatch:  1.4649687 accuracy:  0.78125
# Batch :  2737 / 4687 , BCE in this minibatch:  1.7494907 accuracy:  0.71875
# Batch :  2738 / 4687 , BCE in this minibatch:  0.7464077 accuracy:  0.90625
# Batch :  2739 / 4687 , BCE in this minibatch:  0.3273404 accuracy:  0.9375
# Batch :  2740 / 4687 , BCE in this minibatch:  1.5764956 accuracy:  0.75
# Batch :  2741 / 4687 , BCE in this minibatch:  1.1924193 accuracy:  0.8125
# Batch :  2742 / 4687 , BCE in this minibatch:  1.5011019 accuracy:  0.78125
# Batch :  2743 / 4687 , BCE in this minibatch:  1.7349044 accuracy:  0.78125
# Batch :  2744 / 4687 , BCE in this minibatch:  1.2701995 accuracy:  0.78125
# Batch :  2745 / 4687 , BCE in this minibatch:  0.27827027 accuracy:  0.90625
# Batch :  2746 / 4687 , BCE in this minibatch:  0.373431 accuracy:  0.9375
# Batch :  2747 / 4687 , BCE in this minibatch:  0.78598946 accuracy:  0.78125
# Batch :  2748 / 4687 , BCE in this minibatch:  0.5994184 accuracy:  0.875
# Batch :  2749 / 4687 , BCE in this minibatch:  1.9680853 accuracy:  0.65625
# Batch :  2750 / 4687 , BCE in this minibatch:  1.6279523 accuracy:  0.65625
# Batch :  2751 / 4687 , BCE in this minibatch:  1.9216092 accuracy:  0.625
# Batch :  2752 / 4687 , BCE in this minibatch:  1.49597 accuracy:  0.75
# Batch :  2753 / 4687 , BCE in this minibatch:  1.1938261 accuracy:  0.78125
# Batch :  2754 / 4687 , BCE in this minibatch:  1.3665814 accuracy:  0.78125
# Batch :  2755 / 4687 , BCE in this minibatch:  1.2815714 accuracy:  0.71875
# Batch :  2756 / 4687 , BCE in this minibatch:  1.4881322 accuracy:  0.78125
# Batch :  2757 / 4687 , BCE in this minibatch:  1.1854858 accuracy:  0.71875
# Batch :  2758 / 4687 , BCE in this minibatch:  1.1278949 accuracy:  0.75
# Batch :  2759 / 4687 , BCE in this minibatch:  1.6965228 accuracy:  0.6875
# Batch :  2760 / 4687 , BCE in this minibatch:  2.4532752 accuracy:  0.65625
# Batch :  2761 / 4687 , BCE in this minibatch:  1.5383265 accuracy:  0.78125
# Batch :  2762 / 4687 , BCE in this minibatch:  1.3312804 accuracy:  0.6875
# Batch :  2763 / 4687 , BCE in this minibatch:  1.2622135 accuracy:  0.84375
# Batch :  2764 / 4687 , BCE in this minibatch:  1.5417595 accuracy:  0.75
# Batch :  2765 / 4687 , BCE in this minibatch:  1.762552 accuracy:  0.78125
# Batch :  2766 / 4687 , BCE in this minibatch:  2.7756624 accuracy:  0.71875
# Batch :  2767 / 4687 , BCE in this minibatch:  1.7399735 accuracy:  0.75
# Batch :  2768 / 4687 , BCE in this minibatch:  1.3802338 accuracy:  0.84375
# Batch :  2769 / 4687 , BCE in this minibatch:  1.1535113 accuracy:  0.84375
# Batch :  2770 / 4687 , BCE in this minibatch:  1.3611927 accuracy:  0.75
# Batch :  2771 / 4687 , BCE in this minibatch:  0.5341892 accuracy:  0.84375
# Batch :  2772 / 4687 , BCE in this minibatch:  2.4143653 accuracy:  0.625
# Batch :  2773 / 4687 , BCE in this minibatch:  1.0210848 accuracy:  0.78125
# Batch :  2774 / 4687 , BCE in this minibatch:  1.4310935 accuracy:  0.75
# Batch :  2775 / 4687 , BCE in this minibatch:  0.9385972 accuracy:  0.8125
# Batch :  2776 / 4687 , BCE in this minibatch:  0.39607704 accuracy:  0.90625
# Batch :  2777 / 4687 , BCE in this minibatch:  1.8179847 accuracy:  0.6875
# Batch :  2778 / 4687 , BCE in this minibatch:  2.1144445 accuracy:  0.75
# Batch :  2779 / 4687 , BCE in this minibatch:  1.1419679 accuracy:  0.75
# Batch :  2780 / 4687 , BCE in this minibatch:  0.8263283 accuracy:  0.84375
# Batch :  2781 / 4687 , BCE in this minibatch:  1.6311007 accuracy:  0.71875
# Batch :  2782 / 4687 , BCE in this minibatch:  2.165903 accuracy:  0.6875
# Batch :  2783 / 4687 , BCE in this minibatch:  2.194588 accuracy:  0.71875
# Batch :  2784 / 4687 , BCE in this minibatch:  2.070974 accuracy:  0.6875
# Batch :  2785 / 4687 , BCE in this minibatch:  0.78652585 accuracy:  0.8125
# Batch :  2786 / 4687 , BCE in this minibatch:  1.3844903 accuracy:  0.78125
# Batch :  2787 / 4687 , BCE in this minibatch:  1.2998902 accuracy:  0.78125
# Batch :  2788 / 4687 , BCE in this minibatch:  1.4515709 accuracy:  0.8125
# Batch :  2789 / 4687 , BCE in this minibatch:  0.80370766 accuracy:  0.78125
# Batch :  2790 / 4687 , BCE in this minibatch:  1.0244943 accuracy:  0.84375
# Batch :  2791 / 4687 , BCE in this minibatch:  1.4959034 accuracy:  0.8125
# Batch :  2792 / 4687 , BCE in this minibatch:  1.7036569 accuracy:  0.65625
# Batch :  2793 / 4687 , BCE in this minibatch:  0.951072 accuracy:  0.875
# Batch :  2794 / 4687 , BCE in this minibatch:  1.2329321 accuracy:  0.78125
# Batch :  2795 / 4687 , BCE in this minibatch:  0.97948134 accuracy:  0.75
# Batch :  2796 / 4687 , BCE in this minibatch:  1.6767516 accuracy:  0.78125
# Batch :  2797 / 4687 , BCE in this minibatch:  0.5763763 accuracy:  0.90625
# Batch :  2798 / 4687 , BCE in this minibatch:  1.3468467 accuracy:  0.6875
# Batch :  2799 / 4687 , BCE in this minibatch:  0.97130775 accuracy:  0.75
# Batch :  2800 / 4687 , BCE in this minibatch:  0.8327304 accuracy:  0.8125
# Batch :  2801 / 4687 , BCE in this minibatch:  2.3701522 accuracy:  0.6875
# Batch :  2802 / 4687 , BCE in this minibatch:  1.3794981 accuracy:  0.75
# Batch :  2803 / 4687 , BCE in this minibatch:  0.9195044 accuracy:  0.78125
# Batch :  2804 / 4687 , BCE in this minibatch:  0.5996258 accuracy:  0.9375
# Batch :  2805 / 4687 , BCE in this minibatch:  1.326114 accuracy:  0.78125
# Batch :  2806 / 4687 , BCE in this minibatch:  2.9201684 accuracy:  0.625
# Batch :  2807 / 4687 , BCE in this minibatch:  1.0714514 accuracy:  0.84375
# Batch :  2808 / 4687 , BCE in this minibatch:  1.5426235 accuracy:  0.78125
# Batch :  2809 / 4687 , BCE in this minibatch:  1.3499893 accuracy:  0.8125
# Batch :  2810 / 4687 , BCE in this minibatch:  1.605538 accuracy:  0.8125
# Batch :  2811 / 4687 , BCE in this minibatch:  1.0375395 accuracy:  0.8125
# Batch :  2812 / 4687 , BCE in this minibatch:  1.6381593 accuracy:  0.78125
# Batch :  2813 / 4687 , BCE in this minibatch:  1.0461174 accuracy:  0.75
# Batch :  2814 / 4687 , BCE in this minibatch:  1.7427106 accuracy:  0.71875
# Batch :  2815 / 4687 , BCE in this minibatch:  3.2763247 accuracy:  0.65625
# Batch :  2816 / 4687 , BCE in this minibatch:  1.0983685 accuracy:  0.75
# Batch :  2817 / 4687 , BCE in this minibatch:  1.1422405 accuracy:  0.75
# Batch :  2818 / 4687 , BCE in this minibatch:  1.136682 accuracy:  0.78125
# Batch :  2819 / 4687 , BCE in this minibatch:  0.8456455 accuracy:  0.84375
# Batch :  2820 / 4687 , BCE in this minibatch:  1.4542986 accuracy:  0.78125
# Batch :  2821 / 4687 , BCE in this minibatch:  1.5281835 accuracy:  0.625
# Batch :  2822 / 4687 , BCE in this minibatch:  1.9339027 accuracy:  0.6875
# Batch :  2823 / 4687 , BCE in this minibatch:  0.92251205 accuracy:  0.8125
# Batch :  2824 / 4687 , BCE in this minibatch:  0.8670887 accuracy:  0.875
# Batch :  2825 / 4687 , BCE in this minibatch:  0.7888191 accuracy:  0.90625
# Batch :  2826 / 4687 , BCE in this minibatch:  1.444016 accuracy:  0.8125
# Batch :  2827 / 4687 , BCE in this minibatch:  1.4237977 accuracy:  0.6875
# Batch :  2828 / 4687 , BCE in this minibatch:  2.1033657 accuracy:  0.78125
# Batch :  2829 / 4687 , BCE in this minibatch:  0.91180956 accuracy:  0.71875
# Batch :  2830 / 4687 , BCE in this minibatch:  1.9148355 accuracy:  0.71875
# Batch :  2831 / 4687 , BCE in this minibatch:  1.8530354 accuracy:  0.65625
# Batch :  2832 / 4687 , BCE in this minibatch:  1.7470839 accuracy:  0.6875
# Batch :  2833 / 4687 , BCE in this minibatch:  1.0668089 accuracy:  0.78125
# Batch :  2834 / 4687 , BCE in this minibatch:  1.7107904 accuracy:  0.65625
# Batch :  2835 / 4687 , BCE in this minibatch:  0.55906403 accuracy:  0.8125
# Batch :  2836 / 4687 , BCE in this minibatch:  2.2291372 accuracy:  0.75
# Batch :  2837 / 4687 , BCE in this minibatch:  1.3845751 accuracy:  0.71875
# Batch :  2838 / 4687 , BCE in this minibatch:  1.6616534 accuracy:  0.71875
# Batch :  2839 / 4687 , BCE in this minibatch:  2.0718231 accuracy:  0.75
# Batch :  2840 / 4687 , BCE in this minibatch:  0.7411469 accuracy:  0.875
# Batch :  2841 / 4687 , BCE in this minibatch:  1.2525612 accuracy:  0.8125
# Batch :  2842 / 4687 , BCE in this minibatch:  1.4414008 accuracy:  0.6875
# Batch :  2843 / 4687 , BCE in this minibatch:  0.8226048 accuracy:  0.78125
# Batch :  2844 / 4687 , BCE in this minibatch:  0.99946165 accuracy:  0.71875
# Batch :  2845 / 4687 , BCE in this minibatch:  2.0828028 accuracy:  0.59375
# Batch :  2846 / 4687 , BCE in this minibatch:  3.0278893 accuracy:  0.625
# Batch :  2847 / 4687 , BCE in this minibatch:  1.4172411 accuracy:  0.75
# Batch :  2848 / 4687 , BCE in this minibatch:  0.63865006 accuracy:  0.8125
# Batch :  2849 / 4687 , BCE in this minibatch:  1.3488045 accuracy:  0.6875
# Batch :  2850 / 4687 , BCE in this minibatch:  2.4609299 accuracy:  0.625
# Batch :  2851 / 4687 , BCE in this minibatch:  1.6121721 accuracy:  0.75
# Batch :  2852 / 4687 , BCE in this minibatch:  1.2375948 accuracy:  0.78125
# Batch :  2853 / 4687 , BCE in this minibatch:  1.322497 accuracy:  0.8125
# Batch :  2854 / 4687 , BCE in this minibatch:  1.3789055 accuracy:  0.75
# Batch :  2855 / 4687 , BCE in this minibatch:  2.4789848 accuracy:  0.65625
# Batch :  2856 / 4687 , BCE in this minibatch:  2.0911417 accuracy:  0.59375
# Batch :  2857 / 4687 , BCE in this minibatch:  1.8072283 accuracy:  0.6875
# Batch :  2858 / 4687 , BCE in this minibatch:  1.7721655 accuracy:  0.8125
# Batch :  2859 / 4687 , BCE in this minibatch:  1.2042536 accuracy:  0.875
# Batch :  2860 / 4687 , BCE in this minibatch:  1.1472055 accuracy:  0.84375
# Batch :  2861 / 4687 , BCE in this minibatch:  1.4805727 accuracy:  0.65625
# Batch :  2862 / 4687 , BCE in this minibatch:  1.8342451 accuracy:  0.8125
# Batch :  2863 / 4687 , BCE in this minibatch:  0.751067 accuracy:  0.875
# Batch :  2864 / 4687 , BCE in this minibatch:  2.2789063 accuracy:  0.625
# Batch :  2865 / 4687 , BCE in this minibatch:  1.4354451 accuracy:  0.75
# Batch :  2866 / 4687 , BCE in this minibatch:  1.4540133 accuracy:  0.8125
# Batch :  2867 / 4687 , BCE in this minibatch:  1.9076943 accuracy:  0.71875
# Batch :  2868 / 4687 , BCE in this minibatch:  1.8987229 accuracy:  0.65625
# Batch :  2869 / 4687 , BCE in this minibatch:  0.52488625 accuracy:  0.90625
# Batch :  2870 / 4687 , BCE in this minibatch:  1.8122579 accuracy:  0.6875
# Batch :  2871 / 4687 , BCE in this minibatch:  2.4048955 accuracy:  0.75
# Batch :  2872 / 4687 , BCE in this minibatch:  1.3347263 accuracy:  0.78125
# Batch :  2873 / 4687 , BCE in this minibatch:  1.7198924 accuracy:  0.75
# Batch :  2874 / 4687 , BCE in this minibatch:  1.987236 accuracy:  0.65625
# Batch :  2875 / 4687 , BCE in this minibatch:  2.1791081 accuracy:  0.71875
# Batch :  2876 / 4687 , BCE in this minibatch:  1.089418 accuracy:  0.8125
