# %%
import tensorflow as tf
import numpy as np
from preprocess import *

# %%
embedding_size = 300
batch_size = 32
maxseq_length = 100

# %%
test_data = read_data('data/test.txt')
test_data = np.array(test_data)
test_X = test_data[:,0]
test_Y = test_data[:,[-1]]
len(test_data)
# Out:
# 70488

# %%
model = word2vec_load()

# %%
X = tf.placeholder(tf.float32, shape=[None, maxseq_length * embedding_size])
Y = tf.placeholder(tf.float32, shape=[None, 1])

# %%
with tf.Session() as sess:
    total_batch = int(len(test_X) / batch_size)
    save_path = './saved/model-4'

    sess.run(tf.global_variables_initializer())
    saver = tf.train.import_meta_graph(save_path + '.meta')
    saver.restore(sess, save_path)

    graph = tf.get_default_graph()
    
    W = graph.get_tensor_by_name('weight:0')
    b = graph.get_tensor_by_name('bias:0')
    
    hypothesis = tf.sigmoid(tf.matmul(X, W) + b)
    predicted = tf.cast(hypothesis > 0.5, dtype=tf.float32)
    accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, Y), dtype=tf.float32))
    
    total_acc = 0
    for step in range(total_batch):
        n = step * batch_size
        test_batch_X = test_X[n : n + batch_size]
        test_batch_X = [tokenize(row) for row in test_batch_X]
        test_batch_X = [embedding(model, row) for row in test_batch_X]
        test_batch_X = [zero_padding(maxseq_length, row, embedding_size) for row in test_batch_X]
        test_batch_Y = test_Y[n : n + batch_size]

        acc = sess.run(accuracy , feed_dict={X: test_batch_X, Y: test_batch_Y})
        total_acc += acc * len(test_batch_X)
        print('Batch : ', step + 1, '/', total_batch, 'accuracy: ', float(acc))

    print('accuracy:', float(total_acc/len(test_X)))
# Out:
# INFO:tensorflow:Restoring parameters from ./saved/model-4
# Batch :  1 / 2202 accuracy:  0.875
# Batch :  2 / 2202 accuracy:  0.8125
# Batch :  3 / 2202 accuracy:  0.78125
# Batch :  4 / 2202 accuracy:  0.6875
# Batch :  5 / 2202 accuracy:  0.6875
# Batch :  6 / 2202 accuracy:  0.875
# Batch :  7 / 2202 accuracy:  0.625
# Batch :  8 / 2202 accuracy:  0.78125
# Batch :  9 / 2202 accuracy:  0.8125
# Batch :  10 / 2202 accuracy:  0.71875
# Batch :  11 / 2202 accuracy:  0.71875
# Batch :  12 / 2202 accuracy:  0.84375
# Batch :  13 / 2202 accuracy:  0.6875
# Batch :  14 / 2202 accuracy:  0.6875
# Batch :  15 / 2202 accuracy:  0.78125
# Batch :  16 / 2202 accuracy:  0.875
# Batch :  17 / 2202 accuracy:  0.75
# Batch :  18 / 2202 accuracy:  0.8125
# Batch :  19 / 2202 accuracy:  0.75
# Batch :  20 / 2202 accuracy:  0.65625
# Batch :  21 / 2202 accuracy:  0.6875
# Batch :  22 / 2202 accuracy:  0.8125
# Batch :  23 / 2202 accuracy:  0.65625
# Batch :  24 / 2202 accuracy:  0.75
# Batch :  25 / 2202 accuracy:  0.6875
# Batch :  26 / 2202 accuracy:  0.90625
# Batch :  27 / 2202 accuracy:  0.71875
# Batch :  28 / 2202 accuracy:  0.6875
# Batch :  29 / 2202 accuracy:  0.75
# Batch :  30 / 2202 accuracy:  0.75
# Batch :  31 / 2202 accuracy:  0.65625
# Batch :  32 / 2202 accuracy:  0.90625
# Batch :  33 / 2202 accuracy:  0.71875
# Batch :  34 / 2202 accuracy:  0.78125
# Batch :  35 / 2202 accuracy:  0.75
# Batch :  36 / 2202 accuracy:  0.75
# Batch :  37 / 2202 accuracy:  0.84375
# Batch :  38 / 2202 accuracy:  0.78125
# Batch :  39 / 2202 accuracy:  0.6875
# Batch :  40 / 2202 accuracy:  0.65625
# Batch :  41 / 2202 accuracy:  0.625
# Batch :  42 / 2202 accuracy:  0.8125
# Batch :  43 / 2202 accuracy:  0.75
# Batch :  44 / 2202 accuracy:  0.6875
# Batch :  45 / 2202 accuracy:  0.75
# Batch :  46 / 2202 accuracy:  0.6875
# Batch :  47 / 2202 accuracy:  0.875
# Batch :  48 / 2202 accuracy:  0.6875
# Batch :  49 / 2202 accuracy:  0.71875
# Batch :  50 / 2202 accuracy:  0.75
# Batch :  51 / 2202 accuracy:  0.71875
# Batch :  52 / 2202 accuracy:  0.75
# Batch :  53 / 2202 accuracy:  0.75
# Batch :  54 / 2202 accuracy:  0.75
# Batch :  55 / 2202 accuracy:  0.75
# Batch :  56 / 2202 accuracy:  0.71875
# Batch :  57 / 2202 accuracy:  0.71875
# Batch :  58 / 2202 accuracy:  0.65625
# Batch :  59 / 2202 accuracy:  0.71875
# Batch :  60 / 2202 accuracy:  0.71875
# Batch :  61 / 2202 accuracy:  0.65625
# Batch :  62 / 2202 accuracy:  0.75
# Batch :  63 / 2202 accuracy:  0.78125
# Batch :  64 / 2202 accuracy:  0.6875
# Batch :  65 / 2202 accuracy:  0.65625
# Batch :  66 / 2202 accuracy:  0.75
# Batch :  67 / 2202 accuracy:  0.90625
# Batch :  68 / 2202 accuracy:  0.78125
# Batch :  69 / 2202 accuracy:  0.8125
# Batch :  70 / 2202 accuracy:  0.75
# Batch :  71 / 2202 accuracy:  0.71875
# Batch :  72 / 2202 accuracy:  0.78125
# Batch :  73 / 2202 accuracy:  0.8125
# Batch :  74 / 2202 accuracy:  0.78125
# Batch :  75 / 2202 accuracy:  0.78125
# Batch :  76 / 2202 accuracy:  0.65625
# Batch :  77 / 2202 accuracy:  0.84375
# Batch :  78 / 2202 accuracy:  0.6875
# Batch :  79 / 2202 accuracy:  0.65625
# Batch :  80 / 2202 accuracy:  0.78125
# Batch :  81 / 2202 accuracy:  0.71875
# Batch :  82 / 2202 accuracy:  0.71875
# Batch :  83 / 2202 accuracy:  0.71875
# Batch :  84 / 2202 accuracy:  0.65625
# Batch :  85 / 2202 accuracy:  0.59375
# Batch :  86 / 2202 accuracy:  0.84375
# Batch :  87 / 2202 accuracy:  0.75
# Batch :  88 / 2202 accuracy:  0.8125
# Batch :  89 / 2202 accuracy:  0.78125
# Batch :  90 / 2202 accuracy:  0.71875
# Batch :  91 / 2202 accuracy:  0.84375
# Batch :  92 / 2202 accuracy:  0.8125
# Batch :  93 / 2202 accuracy:  0.875
# Batch :  94 / 2202 accuracy:  0.75
# Batch :  95 / 2202 accuracy:  0.75
# Batch :  96 / 2202 accuracy:  0.65625
# Batch :  97 / 2202 accuracy:  0.84375
# Batch :  98 / 2202 accuracy:  0.71875
# Batch :  99 / 2202 accuracy:  0.78125
# Batch :  100 / 2202 accuracy:  0.6875
# Batch :  101 / 2202 accuracy:  0.75
# Batch :  102 / 2202 accuracy:  0.875
# Batch :  103 / 2202 accuracy:  0.71875
# Batch :  104 / 2202 accuracy:  0.75
# Batch :  105 / 2202 accuracy:  0.75
# Batch :  106 / 2202 accuracy:  0.8125
# Batch :  107 / 2202 accuracy:  0.8125
# Batch :  108 / 2202 accuracy:  0.78125
# Batch :  109 / 2202 accuracy:  0.9375
# Batch :  110 / 2202 accuracy:  0.75
# Batch :  111 / 2202 accuracy:  0.6875
# Batch :  112 / 2202 accuracy:  0.9375
# Batch :  113 / 2202 accuracy:  0.6875
# Batch :  114 / 2202 accuracy:  0.9375
# Batch :  115 / 2202 accuracy:  0.78125
# Batch :  116 / 2202 accuracy:  0.78125
# Batch :  117 / 2202 accuracy:  0.4375
# Batch :  118 / 2202 accuracy:  0.75
# Batch :  119 / 2202 accuracy:  0.78125
# Batch :  120 / 2202 accuracy:  0.875
# Batch :  121 / 2202 accuracy:  0.84375
# Batch :  122 / 2202 accuracy:  0.78125
# Batch :  123 / 2202 accuracy:  0.75
# Batch :  124 / 2202 accuracy:  0.75
# Batch :  125 / 2202 accuracy:  0.75
# Batch :  126 / 2202 accuracy:  0.71875
# Batch :  127 / 2202 accuracy:  0.71875
# Batch :  128 / 2202 accuracy:  0.75
# Batch :  129 / 2202 accuracy:  0.8125
# Batch :  130 / 2202 accuracy:  0.71875
# Batch :  131 / 2202 accuracy:  0.75
# Batch :  132 / 2202 accuracy:  0.625
# Batch :  133 / 2202 accuracy:  0.8125
# Batch :  134 / 2202 accuracy:  0.6875
# Batch :  135 / 2202 accuracy:  0.75
# Batch :  136 / 2202 accuracy:  0.8125
# Batch :  137 / 2202 accuracy:  0.84375
# Batch :  138 / 2202 accuracy:  0.5
# Batch :  139 / 2202 accuracy:  0.65625
# Batch :  140 / 2202 accuracy:  0.75
# Batch :  141 / 2202 accuracy:  0.59375
# Batch :  142 / 2202 accuracy:  0.78125
# Batch :  143 / 2202 accuracy:  0.71875
# Batch :  144 / 2202 accuracy:  0.71875
# Batch :  145 / 2202 accuracy:  0.875
# Batch :  146 / 2202 accuracy:  0.8125
# Batch :  147 / 2202 accuracy:  0.78125
# Batch :  148 / 2202 accuracy:  0.6875
# Batch :  149 / 2202 accuracy:  0.6875
# Batch :  150 / 2202 accuracy:  0.78125
# Batch :  151 / 2202 accuracy:  0.625
# Batch :  152 / 2202 accuracy:  0.78125
# Batch :  153 / 2202 accuracy:  0.6875
# Batch :  154 / 2202 accuracy:  0.78125
# Batch :  155 / 2202 accuracy:  0.75
# Batch :  156 / 2202 accuracy:  0.6875
# Batch :  157 / 2202 accuracy:  0.71875
# Batch :  158 / 2202 accuracy:  0.53125
# Batch :  159 / 2202 accuracy:  0.8125
# Batch :  160 / 2202 accuracy:  0.625
# Batch :  161 / 2202 accuracy:  0.6875
# Batch :  162 / 2202 accuracy:  0.75
# Batch :  163 / 2202 accuracy:  0.6875
# Batch :  164 / 2202 accuracy:  0.75
# Batch :  165 / 2202 accuracy:  0.8125
# Batch :  166 / 2202 accuracy:  0.65625
# Batch :  167 / 2202 accuracy:  0.78125
# Batch :  168 / 2202 accuracy:  0.75
# Batch :  169 / 2202 accuracy:  0.875
# Batch :  170 / 2202 accuracy:  0.875
# Batch :  171 / 2202 accuracy:  0.65625
# Batch :  172 / 2202 accuracy:  0.6875
# Batch :  173 / 2202 accuracy:  0.8125
# Batch :  174 / 2202 accuracy:  0.75
# Batch :  175 / 2202 accuracy:  0.71875
# Batch :  176 / 2202 accuracy:  0.875
# Batch :  177 / 2202 accuracy:  0.75
# Batch :  178 / 2202 accuracy:  0.65625
# Batch :  179 / 2202 accuracy:  0.84375
# Batch :  180 / 2202 accuracy:  0.84375
# Batch :  181 / 2202 accuracy:  0.8125
# Batch :  182 / 2202 accuracy:  0.78125
# Batch :  183 / 2202 accuracy:  0.625
# Batch :  184 / 2202 accuracy:  0.84375
# Batch :  185 / 2202 accuracy:  0.8125
# Batch :  186 / 2202 accuracy:  0.8125
# Batch :  187 / 2202 accuracy:  0.71875
# Batch :  188 / 2202 accuracy:  0.6875
# Batch :  189 / 2202 accuracy:  0.65625
# Batch :  190 / 2202 accuracy:  0.90625
# Batch :  191 / 2202 accuracy:  0.625
# Batch :  192 / 2202 accuracy:  0.78125
# Batch :  193 / 2202 accuracy:  0.78125
# Batch :  194 / 2202 accuracy:  0.625
# Batch :  195 / 2202 accuracy:  0.65625
# Batch :  196 / 2202 accuracy:  0.875
# Batch :  197 / 2202 accuracy:  0.8125
# Batch :  198 / 2202 accuracy:  0.6875
# Batch :  199 / 2202 accuracy:  0.75
# Batch :  200 / 2202 accuracy:  0.84375
# Batch :  201 / 2202 accuracy:  0.78125
# Batch :  202 / 2202 accuracy:  0.78125
# Batch :  203 / 2202 accuracy:  0.875
# Batch :  204 / 2202 accuracy:  0.625
# Batch :  205 / 2202 accuracy:  0.6875
# Batch :  206 / 2202 accuracy:  0.78125
# Batch :  207 / 2202 accuracy:  0.6875
# Batch :  208 / 2202 accuracy:  0.78125
# Batch :  209 / 2202 accuracy:  0.78125
# Batch :  210 / 2202 accuracy:  0.78125
# Batch :  211 / 2202 accuracy:  0.625
# Batch :  212 / 2202 accuracy:  0.75
# Batch :  213 / 2202 accuracy:  0.6875
# Batch :  214 / 2202 accuracy:  0.65625
# Batch :  215 / 2202 accuracy:  0.78125
# Batch :  216 / 2202 accuracy:  0.71875
# Batch :  217 / 2202 accuracy:  0.75
# Batch :  218 / 2202 accuracy:  0.6875
# Batch :  219 / 2202 accuracy:  0.84375
# Batch :  220 / 2202 accuracy:  0.78125
# Batch :  221 / 2202 accuracy:  0.90625
# Batch :  222 / 2202 accuracy:  0.6875
# Batch :  223 / 2202 accuracy:  0.84375
# Batch :  224 / 2202 accuracy:  0.75
# Batch :  225 / 2202 accuracy:  0.78125
# Batch :  226 / 2202 accuracy:  0.75
# Batch :  227 / 2202 accuracy:  0.6875
# Batch :  228 / 2202 accuracy:  0.71875
# Batch :  229 / 2202 accuracy:  0.71875
# Batch :  230 / 2202 accuracy:  0.75
# Batch :  231 / 2202 accuracy:  0.65625
# Batch :  232 / 2202 accuracy:  0.65625
# Batch :  233 / 2202 accuracy:  0.78125
# Batch :  234 / 2202 accuracy:  0.78125
# Batch :  235 / 2202 accuracy:  0.90625
# Batch :  236 / 2202 accuracy:  0.84375
# Batch :  237 / 2202 accuracy:  0.78125
# Batch :  238 / 2202 accuracy:  0.8125
# Batch :  239 / 2202 accuracy:  0.8125
# Batch :  240 / 2202 accuracy:  0.59375
# Batch :  241 / 2202 accuracy:  0.75
# Batch :  242 / 2202 accuracy:  0.8125
# Batch :  243 / 2202 accuracy:  0.78125
# Batch :  244 / 2202 accuracy:  0.84375
# Batch :  245 / 2202 accuracy:  0.6875
# Batch :  246 / 2202 accuracy:  0.6875
# Batch :  247 / 2202 accuracy:  0.53125
# Batch :  248 / 2202 accuracy:  0.75
# Batch :  249 / 2202 accuracy:  0.6875
# Batch :  250 / 2202 accuracy:  0.78125
# Batch :  251 / 2202 accuracy:  0.625
# Batch :  252 / 2202 accuracy:  0.875
# Batch :  253 / 2202 accuracy:  0.8125
# Batch :  254 / 2202 accuracy:  0.65625
# Batch :  255 / 2202 accuracy:  0.65625
# Batch :  256 / 2202 accuracy:  0.8125
# Batch :  257 / 2202 accuracy:  0.90625
# Batch :  258 / 2202 accuracy:  0.8125
# Batch :  259 / 2202 accuracy:  0.71875
# Batch :  260 / 2202 accuracy:  0.65625
# Batch :  261 / 2202 accuracy:  0.6875
# Batch :  262 / 2202 accuracy:  0.78125
# Batch :  263 / 2202 accuracy:  0.59375
# Batch :  264 / 2202 accuracy:  0.71875
# Batch :  265 / 2202 accuracy:  0.78125
# Batch :  266 / 2202 accuracy:  0.75
# Batch :  267 / 2202 accuracy:  0.625
# Batch :  268 / 2202 accuracy:  0.65625
# Batch :  269 / 2202 accuracy:  0.8125
# Batch :  270 / 2202 accuracy:  0.625
# Batch :  271 / 2202 accuracy:  0.75
# Batch :  272 / 2202 accuracy:  0.75
# Batch :  273 / 2202 accuracy:  0.75
# Batch :  274 / 2202 accuracy:  0.65625
# Batch :  275 / 2202 accuracy:  0.78125
# Batch :  276 / 2202 accuracy:  0.78125
# Batch :  277 / 2202 accuracy:  0.78125
# Batch :  278 / 2202 accuracy:  0.75
# Batch :  279 / 2202 accuracy:  0.8125
# Batch :  280 / 2202 accuracy:  0.71875
# Batch :  281 / 2202 accuracy:  0.8125
# Batch :  282 / 2202 accuracy:  0.59375
# Batch :  283 / 2202 accuracy:  0.65625
# Batch :  284 / 2202 accuracy:  0.6875
# Batch :  285 / 2202 accuracy:  0.71875
# Batch :  286 / 2202 accuracy:  0.65625
# Batch :  287 / 2202 accuracy:  0.59375
# Batch :  288 / 2202 accuracy:  0.6875
# Batch :  289 / 2202 accuracy:  0.75
# Batch :  290 / 2202 accuracy:  0.75
# Batch :  291 / 2202 accuracy:  0.8125
# Batch :  292 / 2202 accuracy:  0.78125
# Batch :  293 / 2202 accuracy:  0.875
# Batch :  294 / 2202 accuracy:  0.5625
# Batch :  295 / 2202 accuracy:  0.71875
# Batch :  296 / 2202 accuracy:  0.6875
# Batch :  297 / 2202 accuracy:  0.875
# Batch :  298 / 2202 accuracy:  0.8125
# Batch :  299 / 2202 accuracy:  0.75
# Batch :  300 / 2202 accuracy:  0.71875
# Batch :  301 / 2202 accuracy:  0.78125
# Batch :  302 / 2202 accuracy:  0.75
# Batch :  303 / 2202 accuracy:  0.75
# Batch :  304 / 2202 accuracy:  0.78125
# Batch :  305 / 2202 accuracy:  0.84375
# Batch :  306 / 2202 accuracy:  0.75
# Batch :  307 / 2202 accuracy:  0.59375
# Batch :  308 / 2202 accuracy:  0.8125
# Batch :  309 / 2202 accuracy:  0.875
# Batch :  310 / 2202 accuracy:  0.8125
# Batch :  311 / 2202 accuracy:  0.71875
# Batch :  312 / 2202 accuracy:  0.75
# Batch :  313 / 2202 accuracy:  0.78125
# Batch :  314 / 2202 accuracy:  0.90625
# Batch :  315 / 2202 accuracy:  0.8125
# Batch :  316 / 2202 accuracy:  0.75
# Batch :  317 / 2202 accuracy:  0.71875
# Batch :  318 / 2202 accuracy:  0.78125
# Batch :  319 / 2202 accuracy:  0.75
# Batch :  320 / 2202 accuracy:  0.78125
# Batch :  321 / 2202 accuracy:  0.75
# Batch :  322 / 2202 accuracy:  0.59375
# Batch :  323 / 2202 accuracy:  0.78125
# Batch :  324 / 2202 accuracy:  0.8125
# Batch :  325 / 2202 accuracy:  0.78125
# Batch :  326 / 2202 accuracy:  0.78125
# Batch :  327 / 2202 accuracy:  0.78125
# Batch :  328 / 2202 accuracy:  0.78125
# Batch :  329 / 2202 accuracy:  0.8125
# Batch :  330 / 2202 accuracy:  0.71875
# Batch :  331 / 2202 accuracy:  0.65625
# Batch :  332 / 2202 accuracy:  0.71875
# Batch :  333 / 2202 accuracy:  0.78125
# Batch :  334 / 2202 accuracy:  0.71875
# Batch :  335 / 2202 accuracy:  0.6875
# Batch :  336 / 2202 accuracy:  0.8125
# Batch :  337 / 2202 accuracy:  0.75
# Batch :  338 / 2202 accuracy:  0.84375
# Batch :  339 / 2202 accuracy:  0.6875
# Batch :  340 / 2202 accuracy:  0.8125
# Batch :  341 / 2202 accuracy:  0.84375
# Batch :  342 / 2202 accuracy:  0.78125
# Batch :  343 / 2202 accuracy:  0.8125
# Batch :  344 / 2202 accuracy:  0.75
# Batch :  345 / 2202 accuracy:  0.65625
# Batch :  346 / 2202 accuracy:  0.625
# Batch :  347 / 2202 accuracy:  0.6875
# Batch :  348 / 2202 accuracy:  0.75
# Batch :  349 / 2202 accuracy:  0.65625
# Batch :  350 / 2202 accuracy:  0.78125
# Batch :  351 / 2202 accuracy:  0.71875
# Batch :  352 / 2202 accuracy:  0.6875
# Batch :  353 / 2202 accuracy:  0.71875
# Batch :  354 / 2202 accuracy:  0.71875
# Batch :  355 / 2202 accuracy:  0.84375
# Batch :  356 / 2202 accuracy:  0.78125
# Batch :  357 / 2202 accuracy:  0.625
# Batch :  358 / 2202 accuracy:  0.78125
# Batch :  359 / 2202 accuracy:  0.78125
# Batch :  360 / 2202 accuracy:  0.6875
# Batch :  361 / 2202 accuracy:  0.6875
# Batch :  362 / 2202 accuracy:  0.71875
# Batch :  363 / 2202 accuracy:  0.6875
# Batch :  364 / 2202 accuracy:  0.71875
# Batch :  365 / 2202 accuracy:  0.84375
# Batch :  366 / 2202 accuracy:  0.84375
# Batch :  367 / 2202 accuracy:  0.65625
# Batch :  368 / 2202 accuracy:  0.78125
# Batch :  369 / 2202 accuracy:  0.78125
# Batch :  370 / 2202 accuracy:  0.84375
# Batch :  371 / 2202 accuracy:  0.75
# Batch :  372 / 2202 accuracy:  0.78125
# Batch :  373 / 2202 accuracy:  0.84375
# Batch :  374 / 2202 accuracy:  0.84375
# Batch :  375 / 2202 accuracy:  0.78125
# Batch :  376 / 2202 accuracy:  0.78125
# Batch :  377 / 2202 accuracy:  0.71875
# Batch :  378 / 2202 accuracy:  0.78125
# Batch :  379 / 2202 accuracy:  0.78125
# Batch :  380 / 2202 accuracy:  0.71875
# Batch :  381 / 2202 accuracy:  0.8125
# Batch :  382 / 2202 accuracy:  0.8125
# Batch :  383 / 2202 accuracy:  0.5625
# Batch :  384 / 2202 accuracy:  0.59375
# Batch :  385 / 2202 accuracy:  0.84375
# Batch :  386 / 2202 accuracy:  0.75
# Batch :  387 / 2202 accuracy:  0.65625
# Batch :  388 / 2202 accuracy:  0.71875
# Batch :  389 / 2202 accuracy:  0.875
# Batch :  390 / 2202 accuracy:  0.78125
# Batch :  391 / 2202 accuracy:  0.84375
# Batch :  392 / 2202 accuracy:  0.71875
# Batch :  393 / 2202 accuracy:  0.71875
# Batch :  394 / 2202 accuracy:  0.78125
# Batch :  395 / 2202 accuracy:  0.6875
# Batch :  396 / 2202 accuracy:  0.71875
# Batch :  397 / 2202 accuracy:  0.75
# Batch :  398 / 2202 accuracy:  0.59375
# Batch :  399 / 2202 accuracy:  0.75
# Batch :  400 / 2202 accuracy:  0.78125
# Batch :  401 / 2202 accuracy:  0.78125
# Batch :  402 / 2202 accuracy:  0.75
# Batch :  403 / 2202 accuracy:  0.78125
# Batch :  404 / 2202 accuracy:  0.78125
# Batch :  405 / 2202 accuracy:  0.8125
# Batch :  406 / 2202 accuracy:  0.75
# Batch :  407 / 2202 accuracy:  0.65625
# Batch :  408 / 2202 accuracy:  0.625
# Batch :  409 / 2202 accuracy:  0.75
# Batch :  410 / 2202 accuracy:  0.65625
# Batch :  411 / 2202 accuracy:  0.75
# Batch :  412 / 2202 accuracy:  0.78125
# Batch :  413 / 2202 accuracy:  0.71875
# Batch :  414 / 2202 accuracy:  0.84375
# Batch :  415 / 2202 accuracy:  0.8125
# Batch :  416 / 2202 accuracy:  0.78125
# Batch :  417 / 2202 accuracy:  0.84375
# Batch :  418 / 2202 accuracy:  0.71875
# Batch :  419 / 2202 accuracy:  0.6875
# Batch :  420 / 2202 accuracy:  0.78125
# Batch :  421 / 2202 accuracy:  0.8125
# Batch :  422 / 2202 accuracy:  0.71875
# Batch :  423 / 2202 accuracy:  0.75
# Batch :  424 / 2202 accuracy:  0.90625
# Batch :  425 / 2202 accuracy:  0.71875
# Batch :  426 / 2202 accuracy:  0.8125
# Batch :  427 / 2202 accuracy:  0.71875
# Batch :  428 / 2202 accuracy:  0.875
# Batch :  429 / 2202 accuracy:  0.8125
# Batch :  430 / 2202 accuracy:  0.71875
# Batch :  431 / 2202 accuracy:  0.8125
# Batch :  432 / 2202 accuracy:  0.71875
# Batch :  433 / 2202 accuracy:  0.78125
# Batch :  434 / 2202 accuracy:  0.8125
# Batch :  435 / 2202 accuracy:  0.75
# Batch :  436 / 2202 accuracy:  0.59375
# Batch :  437 / 2202 accuracy:  0.75
# Batch :  438 / 2202 accuracy:  0.78125
# Batch :  439 / 2202 accuracy:  0.75
# Batch :  440 / 2202 accuracy:  0.78125
# Batch :  441 / 2202 accuracy:  0.75
# Batch :  442 / 2202 accuracy:  0.71875
# Batch :  443 / 2202 accuracy:  0.8125
# Batch :  444 / 2202 accuracy:  0.65625
# Batch :  445 / 2202 accuracy:  0.65625
# Batch :  446 / 2202 accuracy:  0.75
# Batch :  447 / 2202 accuracy:  0.6875
# Batch :  448 / 2202 accuracy:  0.625
# Batch :  449 / 2202 accuracy:  0.71875
# Batch :  450 / 2202 accuracy:  0.59375
# Batch :  451 / 2202 accuracy:  0.875
# Batch :  452 / 2202 accuracy:  0.78125
# Batch :  453 / 2202 accuracy:  0.75
# Batch :  454 / 2202 accuracy:  0.625
# Batch :  455 / 2202 accuracy:  0.78125
# Batch :  456 / 2202 accuracy:  0.65625
# Batch :  457 / 2202 accuracy:  0.75
# Batch :  458 / 2202 accuracy:  0.71875
# Batch :  459 / 2202 accuracy:  0.65625
# Batch :  460 / 2202 accuracy:  0.78125
# Batch :  461 / 2202 accuracy:  0.75
# Batch :  462 / 2202 accuracy:  0.65625
# Batch :  463 / 2202 accuracy:  0.75
# Batch :  464 / 2202 accuracy:  0.8125
# Batch :  465 / 2202 accuracy:  0.8125
# Batch :  466 / 2202 accuracy:  0.78125
# Batch :  467 / 2202 accuracy:  0.75
# Batch :  468 / 2202 accuracy:  0.75
# Batch :  469 / 2202 accuracy:  0.75
# Batch :  470 / 2202 accuracy:  0.71875
# Batch :  471 / 2202 accuracy:  0.90625
# Batch :  472 / 2202 accuracy:  0.78125
# Batch :  473 / 2202 accuracy:  0.8125
# Batch :  474 / 2202 accuracy:  0.8125
# Batch :  475 / 2202 accuracy:  0.71875
# Batch :  476 / 2202 accuracy:  0.71875
# Batch :  477 / 2202 accuracy:  0.875
# Batch :  478 / 2202 accuracy:  0.6875
# Batch :  479 / 2202 accuracy:  0.8125
# Batch :  480 / 2202 accuracy:  0.78125
# Batch :  481 / 2202 accuracy:  0.625
# Batch :  482 / 2202 accuracy:  0.84375
# Batch :  483 / 2202 accuracy:  0.78125
# Batch :  484 / 2202 accuracy:  0.75
# Batch :  485 / 2202 accuracy:  0.78125
# Batch :  486 / 2202 accuracy:  0.71875
# Batch :  487 / 2202 accuracy:  0.71875
# Batch :  488 / 2202 accuracy:  0.84375
# Batch :  489 / 2202 accuracy:  0.6875
# Batch :  490 / 2202 accuracy:  0.6875
# Batch :  491 / 2202 accuracy:  0.65625
# Batch :  492 / 2202 accuracy:  0.78125
# Batch :  493 / 2202 accuracy:  0.78125
# Batch :  494 / 2202 accuracy:  0.75
# Batch :  495 / 2202 accuracy:  0.8125
# Batch :  496 / 2202 accuracy:  0.78125
# Batch :  497 / 2202 accuracy:  0.78125
# Batch :  498 / 2202 accuracy:  0.84375
# Batch :  499 / 2202 accuracy:  0.8125
# Batch :  500 / 2202 accuracy:  0.84375
# Batch :  501 / 2202 accuracy:  0.65625
# Batch :  502 / 2202 accuracy:  0.71875
# Batch :  503 / 2202 accuracy:  0.75
# Batch :  504 / 2202 accuracy:  0.78125
# Batch :  505 / 2202 accuracy:  0.6875
# Batch :  506 / 2202 accuracy:  0.6875
# Batch :  507 / 2202 accuracy:  0.8125
# Batch :  508 / 2202 accuracy:  0.75
# Batch :  509 / 2202 accuracy:  0.65625
# Batch :  510 / 2202 accuracy:  0.6875
# Batch :  511 / 2202 accuracy:  0.8125
# Batch :  512 / 2202 accuracy:  0.71875
# Batch :  513 / 2202 accuracy:  0.8125
# Batch :  514 / 2202 accuracy:  0.8125
# Batch :  515 / 2202 accuracy:  0.875
# Batch :  516 / 2202 accuracy:  0.625
# Batch :  517 / 2202 accuracy:  0.8125
# Batch :  518 / 2202 accuracy:  0.65625
# Batch :  519 / 2202 accuracy:  0.84375
# Batch :  520 / 2202 accuracy:  0.75
# Batch :  521 / 2202 accuracy:  0.78125
# Batch :  522 / 2202 accuracy:  0.8125
# Batch :  523 / 2202 accuracy:  0.78125
# Batch :  524 / 2202 accuracy:  0.6875
# Batch :  525 / 2202 accuracy:  0.78125
# Batch :  526 / 2202 accuracy:  0.75
# Batch :  527 / 2202 accuracy:  0.75
# Batch :  528 / 2202 accuracy:  0.71875
# Batch :  529 / 2202 accuracy:  0.78125
# Batch :  530 / 2202 accuracy:  0.84375
# Batch :  531 / 2202 accuracy:  0.75
# Batch :  532 / 2202 accuracy:  0.90625
# Batch :  533 / 2202 accuracy:  0.71875
# Batch :  534 / 2202 accuracy:  0.625
# Batch :  535 / 2202 accuracy:  0.71875
# Batch :  536 / 2202 accuracy:  0.8125
# Batch :  537 / 2202 accuracy:  0.75
# Batch :  538 / 2202 accuracy:  0.84375
# Batch :  539 / 2202 accuracy:  0.6875
# Batch :  540 / 2202 accuracy:  0.65625
# Batch :  541 / 2202 accuracy:  0.75
# Batch :  542 / 2202 accuracy:  0.59375
# Batch :  543 / 2202 accuracy:  0.71875
# Batch :  544 / 2202 accuracy:  0.75
# Batch :  545 / 2202 accuracy:  0.78125
# Batch :  546 / 2202 accuracy:  0.6875
# Batch :  547 / 2202 accuracy:  0.78125
# Batch :  548 / 2202 accuracy:  0.84375
# Batch :  549 / 2202 accuracy:  0.75
# Batch :  550 / 2202 accuracy:  0.625
# Batch :  551 / 2202 accuracy:  0.8125
# Batch :  552 / 2202 accuracy:  0.6875
# Batch :  553 / 2202 accuracy:  0.65625
# Batch :  554 / 2202 accuracy:  0.75
# Batch :  555 / 2202 accuracy:  0.84375
# Batch :  556 / 2202 accuracy:  0.8125
# Batch :  557 / 2202 accuracy:  0.78125
# Batch :  558 / 2202 accuracy:  0.8125
# Batch :  559 / 2202 accuracy:  0.8125
# Batch :  560 / 2202 accuracy:  0.96875
# Batch :  561 / 2202 accuracy:  0.8125
# Batch :  562 / 2202 accuracy:  0.6875
# Batch :  563 / 2202 accuracy:  0.84375
# Batch :  564 / 2202 accuracy:  0.71875
# Batch :  565 / 2202 accuracy:  0.75
# Batch :  566 / 2202 accuracy:  0.84375
# Batch :  567 / 2202 accuracy:  0.78125
# Batch :  568 / 2202 accuracy:  0.75
# Batch :  569 / 2202 accuracy:  0.6875
# Batch :  570 / 2202 accuracy:  0.78125
# Batch :  571 / 2202 accuracy:  0.875
# Batch :  572 / 2202 accuracy:  0.625
# Batch :  573 / 2202 accuracy:  0.6875
# Batch :  574 / 2202 accuracy:  0.6875
# Batch :  575 / 2202 accuracy:  0.8125
# Batch :  576 / 2202 accuracy:  0.75
# Batch :  577 / 2202 accuracy:  0.75
# Batch :  578 / 2202 accuracy:  0.71875
# Batch :  579 / 2202 accuracy:  0.84375
# Batch :  580 / 2202 accuracy:  0.6875
# Batch :  581 / 2202 accuracy:  0.75
# Batch :  582 / 2202 accuracy:  0.625
# Batch :  583 / 2202 accuracy:  0.8125
# Batch :  584 / 2202 accuracy:  0.75
# Batch :  585 / 2202 accuracy:  0.65625
# Batch :  586 / 2202 accuracy:  0.65625
# Batch :  587 / 2202 accuracy:  0.875
# Batch :  588 / 2202 accuracy:  0.625
# Batch :  589 / 2202 accuracy:  0.71875
# Batch :  590 / 2202 accuracy:  0.71875
# Batch :  591 / 2202 accuracy:  0.6875
# Batch :  592 / 2202 accuracy:  0.875
# Batch :  593 / 2202 accuracy:  0.84375
# Batch :  594 / 2202 accuracy:  0.6875
# Batch :  595 / 2202 accuracy:  0.75
# Batch :  596 / 2202 accuracy:  0.84375
# Batch :  597 / 2202 accuracy:  0.875
# Batch :  598 / 2202 accuracy:  0.84375
# Batch :  599 / 2202 accuracy:  0.59375
# Batch :  600 / 2202 accuracy:  0.65625
# Batch :  601 / 2202 accuracy:  0.78125
# Batch :  602 / 2202 accuracy:  0.71875
# Batch :  603 / 2202 accuracy:  0.84375
# Batch :  604 / 2202 accuracy:  0.71875
# Batch :  605 / 2202 accuracy:  0.65625
# Batch :  606 / 2202 accuracy:  0.78125
# Batch :  607 / 2202 accuracy:  0.75
# Batch :  608 / 2202 accuracy:  0.75
# Batch :  609 / 2202 accuracy:  0.78125
# Batch :  610 / 2202 accuracy:  0.78125
# Batch :  611 / 2202 accuracy:  0.71875
# Batch :  612 / 2202 accuracy:  0.9375
# Batch :  613 / 2202 accuracy:  0.875
# Batch :  614 / 2202 accuracy:  0.6875
# Batch :  615 / 2202 accuracy:  0.625
# Batch :  616 / 2202 accuracy:  0.65625
# Batch :  617 / 2202 accuracy:  0.71875
# Batch :  618 / 2202 accuracy:  0.75
# Batch :  619 / 2202 accuracy:  0.78125
# Batch :  620 / 2202 accuracy:  0.65625
# Batch :  621 / 2202 accuracy:  0.65625
# Batch :  622 / 2202 accuracy:  0.8125
# Batch :  623 / 2202 accuracy:  0.6875
# Batch :  624 / 2202 accuracy:  0.65625
# Batch :  625 / 2202 accuracy:  0.84375
# Batch :  626 / 2202 accuracy:  0.875
# Batch :  627 / 2202 accuracy:  0.84375
# Batch :  628 / 2202 accuracy:  0.71875
# Batch :  629 / 2202 accuracy:  0.90625
# Batch :  630 / 2202 accuracy:  0.78125
# Batch :  631 / 2202 accuracy:  0.78125
# Batch :  632 / 2202 accuracy:  0.78125
# Batch :  633 / 2202 accuracy:  0.75
# Batch :  634 / 2202 accuracy:  0.78125
# Batch :  635 / 2202 accuracy:  0.78125
# Batch :  636 / 2202 accuracy:  0.71875
# Batch :  637 / 2202 accuracy:  0.75
# Batch :  638 / 2202 accuracy:  0.84375
# Batch :  639 / 2202 accuracy:  0.84375
# Batch :  640 / 2202 accuracy:  0.65625
# Batch :  641 / 2202 accuracy:  0.71875
# Batch :  642 / 2202 accuracy:  0.78125
# Batch :  643 / 2202 accuracy:  0.71875
# Batch :  644 / 2202 accuracy:  0.78125
# Batch :  645 / 2202 accuracy:  0.6875
# Batch :  646 / 2202 accuracy:  0.875
# Batch :  647 / 2202 accuracy:  0.9375
# Batch :  648 / 2202 accuracy:  0.71875
# Batch :  649 / 2202 accuracy:  0.65625
# Batch :  650 / 2202 accuracy:  0.75
# Batch :  651 / 2202 accuracy:  0.75
# Batch :  652 / 2202 accuracy:  0.90625
# Batch :  653 / 2202 accuracy:  0.8125
# Batch :  654 / 2202 accuracy:  0.75
# Batch :  655 / 2202 accuracy:  0.6875
# Batch :  656 / 2202 accuracy:  0.6875
# Batch :  657 / 2202 accuracy:  0.875
# Batch :  658 / 2202 accuracy:  0.75
# Batch :  659 / 2202 accuracy:  0.75
# Batch :  660 / 2202 accuracy:  0.84375
# Batch :  661 / 2202 accuracy:  0.75
# Batch :  662 / 2202 accuracy:  0.8125
# Batch :  663 / 2202 accuracy:  0.78125
# Batch :  664 / 2202 accuracy:  0.71875
# Batch :  665 / 2202 accuracy:  0.90625
# Batch :  666 / 2202 accuracy:  0.8125
# Batch :  667 / 2202 accuracy:  0.84375
# Batch :  668 / 2202 accuracy:  0.75
# Batch :  669 / 2202 accuracy:  0.90625
# Batch :  670 / 2202 accuracy:  0.75
# Batch :  671 / 2202 accuracy:  0.6875
# Batch :  672 / 2202 accuracy:  0.78125
# Batch :  673 / 2202 accuracy:  0.875
# Batch :  674 / 2202 accuracy:  0.6875
# Batch :  675 / 2202 accuracy:  0.75
# Batch :  676 / 2202 accuracy:  0.75
# Batch :  677 / 2202 accuracy:  0.65625
# Batch :  678 / 2202 accuracy:  0.65625
# Batch :  679 / 2202 accuracy:  0.71875
# Batch :  680 / 2202 accuracy:  0.75
# Batch :  681 / 2202 accuracy:  0.71875
# Batch :  682 / 2202 accuracy:  0.71875
# Batch :  683 / 2202 accuracy:  0.75
# Batch :  684 / 2202 accuracy:  0.875
# Batch :  685 / 2202 accuracy:  0.78125
# Batch :  686 / 2202 accuracy:  0.71875
# Batch :  687 / 2202 accuracy:  0.59375
# Batch :  688 / 2202 accuracy:  0.84375
# Batch :  689 / 2202 accuracy:  0.65625
# Batch :  690 / 2202 accuracy:  0.8125
# Batch :  691 / 2202 accuracy:  0.8125
# Batch :  692 / 2202 accuracy:  0.71875
# Batch :  693 / 2202 accuracy:  0.78125
# Batch :  694 / 2202 accuracy:  0.625
# Batch :  695 / 2202 accuracy:  0.59375
# Batch :  696 / 2202 accuracy:  0.625
# Batch :  697 / 2202 accuracy:  0.71875
# Batch :  698 / 2202 accuracy:  0.78125
# Batch :  699 / 2202 accuracy:  0.6875
# Batch :  700 / 2202 accuracy:  0.875
# Batch :  701 / 2202 accuracy:  0.84375
# Batch :  702 / 2202 accuracy:  0.71875
# Batch :  703 / 2202 accuracy:  0.75
# Batch :  704 / 2202 accuracy:  0.84375
# Batch :  705 / 2202 accuracy:  0.6875
# Batch :  706 / 2202 accuracy:  0.78125
# Batch :  707 / 2202 accuracy:  0.6875
# Batch :  708 / 2202 accuracy:  0.71875
# Batch :  709 / 2202 accuracy:  0.8125
# Batch :  710 / 2202 accuracy:  0.6875
# Batch :  711 / 2202 accuracy:  0.71875
# Batch :  712 / 2202 accuracy:  0.78125
# Batch :  713 / 2202 accuracy:  0.71875
# Batch :  714 / 2202 accuracy:  0.65625
# Batch :  715 / 2202 accuracy:  0.84375
# Batch :  716 / 2202 accuracy:  0.8125
# Batch :  717 / 2202 accuracy:  0.78125
# Batch :  718 / 2202 accuracy:  0.75
# Batch :  719 / 2202 accuracy:  0.84375
# Batch :  720 / 2202 accuracy:  0.71875
# Batch :  721 / 2202 accuracy:  0.71875
# Batch :  722 / 2202 accuracy:  0.71875
# Batch :  723 / 2202 accuracy:  0.65625
# Batch :  724 / 2202 accuracy:  0.59375
# Batch :  725 / 2202 accuracy:  0.6875
# Batch :  726 / 2202 accuracy:  0.75
# Batch :  727 / 2202 accuracy:  0.6875
# Batch :  728 / 2202 accuracy:  0.75
# Batch :  729 / 2202 accuracy:  0.8125
# Batch :  730 / 2202 accuracy:  0.78125
# Batch :  731 / 2202 accuracy:  0.8125
# Batch :  732 / 2202 accuracy:  0.71875
# Batch :  733 / 2202 accuracy:  0.78125
# Batch :  734 / 2202 accuracy:  0.625
# Batch :  735 / 2202 accuracy:  0.75
# Batch :  736 / 2202 accuracy:  0.71875
# Batch :  737 / 2202 accuracy:  0.59375
# Batch :  738 / 2202 accuracy:  0.71875
# Batch :  739 / 2202 accuracy:  0.75
# Batch :  740 / 2202 accuracy:  0.8125
# Batch :  741 / 2202 accuracy:  0.75
# Batch :  742 / 2202 accuracy:  0.6875
# Batch :  743 / 2202 accuracy:  0.78125
# Batch :  744 / 2202 accuracy:  0.78125
# Batch :  745 / 2202 accuracy:  0.75
# Batch :  746 / 2202 accuracy:  0.71875
# Batch :  747 / 2202 accuracy:  0.75
# Batch :  748 / 2202 accuracy:  0.71875
# Batch :  749 / 2202 accuracy:  0.65625
# Batch :  750 / 2202 accuracy:  0.8125
# Batch :  751 / 2202 accuracy:  0.71875
# Batch :  752 / 2202 accuracy:  0.84375
# Batch :  753 / 2202 accuracy:  0.8125
# Batch :  754 / 2202 accuracy:  0.78125
# Batch :  755 / 2202 accuracy:  0.78125
# Batch :  756 / 2202 accuracy:  0.59375
# Batch :  757 / 2202 accuracy:  0.59375
# Batch :  758 / 2202 accuracy:  0.625
# Batch :  759 / 2202 accuracy:  0.75
# Batch :  760 / 2202 accuracy:  0.8125
# Batch :  761 / 2202 accuracy:  0.8125
# Batch :  762 / 2202 accuracy:  0.75
# Batch :  763 / 2202 accuracy:  0.78125
# Batch :  764 / 2202 accuracy:  0.75
# Batch :  765 / 2202 accuracy:  0.8125
# Batch :  766 / 2202 accuracy:  0.75
# Batch :  767 / 2202 accuracy:  0.6875
# Batch :  768 / 2202 accuracy:  0.6875
# Batch :  769 / 2202 accuracy:  0.78125
# Batch :  770 / 2202 accuracy:  0.71875
# Batch :  771 / 2202 accuracy:  0.78125
# Batch :  772 / 2202 accuracy:  0.75
# Batch :  773 / 2202 accuracy:  0.59375
# Batch :  774 / 2202 accuracy:  0.78125
# Batch :  775 / 2202 accuracy:  0.90625
# Batch :  776 / 2202 accuracy:  0.71875
# Batch :  777 / 2202 accuracy:  0.75
# Batch :  778 / 2202 accuracy:  0.84375
# Batch :  779 / 2202 accuracy:  0.6875
# Batch :  780 / 2202 accuracy:  0.5625
# Batch :  781 / 2202 accuracy:  0.78125
# Batch :  782 / 2202 accuracy:  0.84375
# Batch :  783 / 2202 accuracy:  0.78125
# Batch :  784 / 2202 accuracy:  0.75
# Batch :  785 / 2202 accuracy:  0.75
# Batch :  786 / 2202 accuracy:  0.8125
# Batch :  787 / 2202 accuracy:  0.75
# Batch :  788 / 2202 accuracy:  0.65625
# Batch :  789 / 2202 accuracy:  0.65625
# Batch :  790 / 2202 accuracy:  0.84375
# Batch :  791 / 2202 accuracy:  0.5
# Batch :  792 / 2202 accuracy:  0.84375
# Batch :  793 / 2202 accuracy:  0.71875
# Batch :  794 / 2202 accuracy:  0.78125
# Batch :  795 / 2202 accuracy:  0.75
# Batch :  796 / 2202 accuracy:  0.6875
# Batch :  797 / 2202 accuracy:  0.71875
# Batch :  798 / 2202 accuracy:  0.78125
# Batch :  799 / 2202 accuracy:  0.75
# Batch :  800 / 2202 accuracy:  0.78125
# Batch :  801 / 2202 accuracy:  0.75
# Batch :  802 / 2202 accuracy:  0.5625
# Batch :  803 / 2202 accuracy:  0.8125
# Batch :  804 / 2202 accuracy:  0.625
# Batch :  805 / 2202 accuracy:  0.71875
# Batch :  806 / 2202 accuracy:  0.75
# Batch :  807 / 2202 accuracy:  0.78125
# Batch :  808 / 2202 accuracy:  0.75
# Batch :  809 / 2202 accuracy:  0.78125
# Batch :  810 / 2202 accuracy:  0.75
# Batch :  811 / 2202 accuracy:  0.875
# Batch :  812 / 2202 accuracy:  0.8125
# Batch :  813 / 2202 accuracy:  0.75
# Batch :  814 / 2202 accuracy:  0.875
# Batch :  815 / 2202 accuracy:  0.625
# Batch :  816 / 2202 accuracy:  0.8125
# Batch :  817 / 2202 accuracy:  0.71875
# Batch :  818 / 2202 accuracy:  0.78125
# Batch :  819 / 2202 accuracy:  0.8125
# Batch :  820 / 2202 accuracy:  0.8125
# Batch :  821 / 2202 accuracy:  0.6875
# Batch :  822 / 2202 accuracy:  0.6875
# Batch :  823 / 2202 accuracy:  0.78125
# Batch :  824 / 2202 accuracy:  0.71875
# Batch :  825 / 2202 accuracy:  0.875
# Batch :  826 / 2202 accuracy:  0.8125
# Batch :  827 / 2202 accuracy:  0.78125
# Batch :  828 / 2202 accuracy:  0.6875
# Batch :  829 / 2202 accuracy:  0.6875
# Batch :  830 / 2202 accuracy:  0.75
# Batch :  831 / 2202 accuracy:  0.8125
# Batch :  832 / 2202 accuracy:  0.5
# Batch :  833 / 2202 accuracy:  0.78125
# Batch :  834 / 2202 accuracy:  0.71875
# Batch :  835 / 2202 accuracy:  0.78125
# Batch :  836 / 2202 accuracy:  0.78125
# Batch :  837 / 2202 accuracy:  0.71875
# Batch :  838 / 2202 accuracy:  0.84375
# Batch :  839 / 2202 accuracy:  0.6875
# Batch :  840 / 2202 accuracy:  0.8125
# Batch :  841 / 2202 accuracy:  0.78125
# Batch :  842 / 2202 accuracy:  0.875
# Batch :  843 / 2202 accuracy:  0.75
# Batch :  844 / 2202 accuracy:  0.6875
# Batch :  845 / 2202 accuracy:  0.84375
# Batch :  846 / 2202 accuracy:  0.59375
# Batch :  847 / 2202 accuracy:  0.8125
# Batch :  848 / 2202 accuracy:  0.65625
# Batch :  849 / 2202 accuracy:  0.71875
# Batch :  850 / 2202 accuracy:  0.71875
# Batch :  851 / 2202 accuracy:  0.78125
# Batch :  852 / 2202 accuracy:  0.78125
# Batch :  853 / 2202 accuracy:  0.71875
# Batch :  854 / 2202 accuracy:  0.75
# Batch :  855 / 2202 accuracy:  0.75
# Batch :  856 / 2202 accuracy:  0.90625
# Batch :  857 / 2202 accuracy:  0.8125
# Batch :  858 / 2202 accuracy:  0.75
# Batch :  859 / 2202 accuracy:  0.90625
# Batch :  860 / 2202 accuracy:  0.71875
# Batch :  861 / 2202 accuracy:  0.65625
# Batch :  862 / 2202 accuracy:  0.875
# Batch :  863 / 2202 accuracy:  0.71875
# Batch :  864 / 2202 accuracy:  0.875
# Batch :  865 / 2202 accuracy:  0.71875
# Batch :  866 / 2202 accuracy:  0.53125
# Batch :  867 / 2202 accuracy:  0.84375
# Batch :  868 / 2202 accuracy:  0.65625
# Batch :  869 / 2202 accuracy:  0.65625
# Batch :  870 / 2202 accuracy:  0.875
# Batch :  871 / 2202 accuracy:  0.75
# Batch :  872 / 2202 accuracy:  0.625
# Batch :  873 / 2202 accuracy:  0.65625
# Batch :  874 / 2202 accuracy:  0.6875
# Batch :  875 / 2202 accuracy:  0.8125
# Batch :  876 / 2202 accuracy:  0.75
# Batch :  877 / 2202 accuracy:  0.75
# Batch :  878 / 2202 accuracy:  0.8125
# Batch :  879 / 2202 accuracy:  0.78125
# Batch :  880 / 2202 accuracy:  0.625
# Batch :  881 / 2202 accuracy:  0.71875
# Batch :  882 / 2202 accuracy:  0.75
# Batch :  883 / 2202 accuracy:  0.75
# Batch :  884 / 2202 accuracy:  0.65625
# Batch :  885 / 2202 accuracy:  0.71875
# Batch :  886 / 2202 accuracy:  0.90625
# Batch :  887 / 2202 accuracy:  0.8125
# Batch :  888 / 2202 accuracy:  0.84375
# Batch :  889 / 2202 accuracy:  0.625
# Batch :  890 / 2202 accuracy:  0.71875
# Batch :  891 / 2202 accuracy:  0.71875
# Batch :  892 / 2202 accuracy:  0.625
# Batch :  893 / 2202 accuracy:  0.6875
# Batch :  894 / 2202 accuracy:  0.71875
# Batch :  895 / 2202 accuracy:  0.8125
# Batch :  896 / 2202 accuracy:  0.75
# Batch :  897 / 2202 accuracy:  0.84375
# Batch :  898 / 2202 accuracy:  0.90625
# Batch :  899 / 2202 accuracy:  0.84375
# Batch :  900 / 2202 accuracy:  0.75
# Batch :  901 / 2202 accuracy:  0.71875
# Batch :  902 / 2202 accuracy:  0.71875
# Batch :  903 / 2202 accuracy:  0.78125
# Batch :  904 / 2202 accuracy:  0.78125
# Batch :  905 / 2202 accuracy:  0.8125
# Batch :  906 / 2202 accuracy:  0.90625
# Batch :  907 / 2202 accuracy:  0.625
# Batch :  908 / 2202 accuracy:  0.71875
# Batch :  909 / 2202 accuracy:  0.8125
# Batch :  910 / 2202 accuracy:  0.8125
# Batch :  911 / 2202 accuracy:  0.6875
# Batch :  912 / 2202 accuracy:  0.75
# Batch :  913 / 2202 accuracy:  0.71875
# Batch :  914 / 2202 accuracy:  0.78125
# Batch :  915 / 2202 accuracy:  0.65625
# Batch :  916 / 2202 accuracy:  0.71875
# Batch :  917 / 2202 accuracy:  0.8125
# Batch :  918 / 2202 accuracy:  0.6875
# Batch :  919 / 2202 accuracy:  0.78125
# Batch :  920 / 2202 accuracy:  0.84375
# Batch :  921 / 2202 accuracy:  0.71875
# Batch :  922 / 2202 accuracy:  0.75
# Batch :  923 / 2202 accuracy:  0.65625
# Batch :  924 / 2202 accuracy:  0.71875
# Batch :  925 / 2202 accuracy:  0.71875
# Batch :  926 / 2202 accuracy:  0.78125
# Batch :  927 / 2202 accuracy:  0.84375
# Batch :  928 / 2202 accuracy:  0.78125
# Batch :  929 / 2202 accuracy:  0.8125
# Batch :  930 / 2202 accuracy:  0.59375
# Batch :  931 / 2202 accuracy:  0.75
# Batch :  932 / 2202 accuracy:  0.71875
# Batch :  933 / 2202 accuracy:  0.625
# Batch :  934 / 2202 accuracy:  0.78125
# Batch :  935 / 2202 accuracy:  0.625
# Batch :  936 / 2202 accuracy:  0.78125
# Batch :  937 / 2202 accuracy:  0.5625
# Batch :  938 / 2202 accuracy:  0.59375
# Batch :  939 / 2202 accuracy:  0.625
# Batch :  940 / 2202 accuracy:  0.625
# Batch :  941 / 2202 accuracy:  0.75
# Batch :  942 / 2202 accuracy:  0.78125
# Batch :  943 / 2202 accuracy:  0.78125
# Batch :  944 / 2202 accuracy:  0.6875
# Batch :  945 / 2202 accuracy:  0.75
# Batch :  946 / 2202 accuracy:  0.59375
# Batch :  947 / 2202 accuracy:  0.78125
# Batch :  948 / 2202 accuracy:  0.75
# Batch :  949 / 2202 accuracy:  0.84375
# Batch :  950 / 2202 accuracy:  0.78125
# Batch :  951 / 2202 accuracy:  0.90625
# Batch :  952 / 2202 accuracy:  0.6875
# Batch :  953 / 2202 accuracy:  0.65625
# Batch :  954 / 2202 accuracy:  0.6875
# Batch :  955 / 2202 accuracy:  0.84375
# Batch :  956 / 2202 accuracy:  0.78125
# Batch :  957 / 2202 accuracy:  0.8125
# Batch :  958 / 2202 accuracy:  0.84375
# Batch :  959 / 2202 accuracy:  0.78125
# Batch :  960 / 2202 accuracy:  0.65625
# Batch :  961 / 2202 accuracy:  0.8125
# Batch :  962 / 2202 accuracy:  0.65625
# Batch :  963 / 2202 accuracy:  0.65625
# Batch :  964 / 2202 accuracy:  0.6875
# Batch :  965 / 2202 accuracy:  0.84375
# Batch :  966 / 2202 accuracy:  0.90625
# Batch :  967 / 2202 accuracy:  0.65625
# Batch :  968 / 2202 accuracy:  0.6875
# Batch :  969 / 2202 accuracy:  0.75
# Batch :  970 / 2202 accuracy:  0.65625
# Batch :  971 / 2202 accuracy:  0.8125
# Batch :  972 / 2202 accuracy:  0.78125
# Batch :  973 / 2202 accuracy:  0.8125
# Batch :  974 / 2202 accuracy:  0.84375
# Batch :  975 / 2202 accuracy:  0.75
# Batch :  976 / 2202 accuracy:  1.0
# Batch :  977 / 2202 accuracy:  0.78125
# Batch :  978 / 2202 accuracy:  0.6875
# Batch :  979 / 2202 accuracy:  0.78125
# Batch :  980 / 2202 accuracy:  0.625
# Batch :  981 / 2202 accuracy:  0.78125
# Batch :  982 / 2202 accuracy:  0.78125
# Batch :  983 / 2202 accuracy:  0.625
# Batch :  984 / 2202 accuracy:  0.6875
# Batch :  985 / 2202 accuracy:  0.75
# Batch :  986 / 2202 accuracy:  0.5625
# Batch :  987 / 2202 accuracy:  0.75
# Batch :  988 / 2202 accuracy:  0.75
# Batch :  989 / 2202 accuracy:  0.78125
# Batch :  990 / 2202 accuracy:  0.6875
# Batch :  991 / 2202 accuracy:  0.875
# Batch :  992 / 2202 accuracy:  0.90625
# Batch :  993 / 2202 accuracy:  0.75
# Batch :  994 / 2202 accuracy:  0.71875
# Batch :  995 / 2202 accuracy:  0.84375
# Batch :  996 / 2202 accuracy:  0.84375
# Batch :  997 / 2202 accuracy:  0.6875
# Batch :  998 / 2202 accuracy:  0.65625
# Batch :  999 / 2202 accuracy:  0.6875
# Batch :  1000 / 2202 accuracy:  0.78125
# Batch :  1001 / 2202 accuracy:  0.65625
# Batch :  1002 / 2202 accuracy:  0.71875
# Batch :  1003 / 2202 accuracy:  0.875
# Batch :  1004 / 2202 accuracy:  0.75
# Batch :  1005 / 2202 accuracy:  0.71875
# Batch :  1006 / 2202 accuracy:  0.84375
# Batch :  1007 / 2202 accuracy:  0.75
# Batch :  1008 / 2202 accuracy:  0.6875
# Batch :  1009 / 2202 accuracy:  0.71875
# Batch :  1010 / 2202 accuracy:  0.71875
# Batch :  1011 / 2202 accuracy:  0.625
# Batch :  1012 / 2202 accuracy:  0.71875
# Batch :  1013 / 2202 accuracy:  0.71875
# Batch :  1014 / 2202 accuracy:  0.71875
# Batch :  1015 / 2202 accuracy:  0.625
# Batch :  1016 / 2202 accuracy:  0.65625
# Batch :  1017 / 2202 accuracy:  0.84375
# Batch :  1018 / 2202 accuracy:  0.875
# Batch :  1019 / 2202 accuracy:  0.625
# Batch :  1020 / 2202 accuracy:  0.8125
# Batch :  1021 / 2202 accuracy:  0.78125
# Batch :  1022 / 2202 accuracy:  0.90625
# Batch :  1023 / 2202 accuracy:  0.71875
# Batch :  1024 / 2202 accuracy:  0.71875
# Batch :  1025 / 2202 accuracy:  0.65625
# Batch :  1026 / 2202 accuracy:  0.625
# Batch :  1027 / 2202 accuracy:  0.78125
# Batch :  1028 / 2202 accuracy:  0.6875
# Batch :  1029 / 2202 accuracy:  0.71875
# Batch :  1030 / 2202 accuracy:  0.875
# Batch :  1031 / 2202 accuracy:  0.6875
# Batch :  1032 / 2202 accuracy:  0.78125
# Batch :  1033 / 2202 accuracy:  0.625
# Batch :  1034 / 2202 accuracy:  0.59375
# Batch :  1035 / 2202 accuracy:  0.625
# Batch :  1036 / 2202 accuracy:  0.75
# Batch :  1037 / 2202 accuracy:  0.75
# Batch :  1038 / 2202 accuracy:  0.71875
# Batch :  1039 / 2202 accuracy:  0.8125
# Batch :  1040 / 2202 accuracy:  0.8125
# Batch :  1041 / 2202 accuracy:  0.78125
# Batch :  1042 / 2202 accuracy:  0.71875
# Batch :  1043 / 2202 accuracy:  0.875
# Batch :  1044 / 2202 accuracy:  0.6875
# Batch :  1045 / 2202 accuracy:  0.78125
# Batch :  1046 / 2202 accuracy:  0.875
# Batch :  1047 / 2202 accuracy:  0.59375
# Batch :  1048 / 2202 accuracy:  0.8125
# Batch :  1049 / 2202 accuracy:  0.6875
# Batch :  1050 / 2202 accuracy:  0.78125
# Batch :  1051 / 2202 accuracy:  0.78125
# Batch :  1052 / 2202 accuracy:  0.75
# Batch :  1053 / 2202 accuracy:  0.71875
# Batch :  1054 / 2202 accuracy:  0.6875
# Batch :  1055 / 2202 accuracy:  0.78125
# Batch :  1056 / 2202 accuracy:  0.8125
# Batch :  1057 / 2202 accuracy:  0.6875
# Batch :  1058 / 2202 accuracy:  0.65625
# Batch :  1059 / 2202 accuracy:  0.8125
# Batch :  1060 / 2202 accuracy:  0.9375
# Batch :  1061 / 2202 accuracy:  0.8125
# Batch :  1062 / 2202 accuracy:  0.6875
# Batch :  1063 / 2202 accuracy:  0.875
# Batch :  1064 / 2202 accuracy:  0.84375
# Batch :  1065 / 2202 accuracy:  0.65625
# Batch :  1066 / 2202 accuracy:  0.71875
# Batch :  1067 / 2202 accuracy:  0.84375
# Batch :  1068 / 2202 accuracy:  0.71875
# Batch :  1069 / 2202 accuracy:  0.78125
# Batch :  1070 / 2202 accuracy:  0.6875
# Batch :  1071 / 2202 accuracy:  0.75
# Batch :  1072 / 2202 accuracy:  0.84375
# Batch :  1073 / 2202 accuracy:  0.8125
# Batch :  1074 / 2202 accuracy:  0.84375
# Batch :  1075 / 2202 accuracy:  0.65625
# Batch :  1076 / 2202 accuracy:  0.78125
# Batch :  1077 / 2202 accuracy:  0.6875
# Batch :  1078 / 2202 accuracy:  0.75
# Batch :  1079 / 2202 accuracy:  0.78125
# Batch :  1080 / 2202 accuracy:  0.71875
# Batch :  1081 / 2202 accuracy:  0.6875
# Batch :  1082 / 2202 accuracy:  0.6875
# Batch :  1083 / 2202 accuracy:  0.8125
# Batch :  1084 / 2202 accuracy:  0.625
# Batch :  1085 / 2202 accuracy:  0.78125
# Batch :  1086 / 2202 accuracy:  0.71875
# Batch :  1087 / 2202 accuracy:  0.8125
# Batch :  1088 / 2202 accuracy:  0.75
# Batch :  1089 / 2202 accuracy:  0.65625
# Batch :  1090 / 2202 accuracy:  0.75
# Batch :  1091 / 2202 accuracy:  0.71875
# Batch :  1092 / 2202 accuracy:  0.65625
# Batch :  1093 / 2202 accuracy:  0.6875
# Batch :  1094 / 2202 accuracy:  0.875
# Batch :  1095 / 2202 accuracy:  0.8125
# Batch :  1096 / 2202 accuracy:  0.75
# Batch :  1097 / 2202 accuracy:  0.78125
# Batch :  1098 / 2202 accuracy:  0.78125
# Batch :  1099 / 2202 accuracy:  0.6875
# Batch :  1100 / 2202 accuracy:  0.6875
# Batch :  1101 / 2202 accuracy:  0.71875
# Batch :  1102 / 2202 accuracy:  0.875
# Batch :  1103 / 2202 accuracy:  0.71875
# Batch :  1104 / 2202 accuracy:  0.84375
# Batch :  1105 / 2202 accuracy:  0.65625
# Batch :  1106 / 2202 accuracy:  0.8125
# Batch :  1107 / 2202 accuracy:  0.78125
# Batch :  1108 / 2202 accuracy:  0.6875
# Batch :  1109 / 2202 accuracy:  0.75
# Batch :  1110 / 2202 accuracy:  0.78125
# Batch :  1111 / 2202 accuracy:  0.8125
# Batch :  1112 / 2202 accuracy:  0.8125
# Batch :  1113 / 2202 accuracy:  0.8125
# Batch :  1114 / 2202 accuracy:  0.8125
# Batch :  1115 / 2202 accuracy:  0.90625
# Batch :  1116 / 2202 accuracy:  0.65625
# Batch :  1117 / 2202 accuracy:  0.6875
# Batch :  1118 / 2202 accuracy:  0.8125
# Batch :  1119 / 2202 accuracy:  0.78125
# Batch :  1120 / 2202 accuracy:  0.78125
# Batch :  1121 / 2202 accuracy:  0.71875
# Batch :  1122 / 2202 accuracy:  0.78125
# Batch :  1123 / 2202 accuracy:  0.8125
# Batch :  1124 / 2202 accuracy:  0.625
# Batch :  1125 / 2202 accuracy:  0.84375
# Batch :  1126 / 2202 accuracy:  0.65625
# Batch :  1127 / 2202 accuracy:  0.53125
# Batch :  1128 / 2202 accuracy:  0.71875
# Batch :  1129 / 2202 accuracy:  0.6875
# Batch :  1130 / 2202 accuracy:  0.625
# Batch :  1131 / 2202 accuracy:  0.875
# Batch :  1132 / 2202 accuracy:  0.6875
# Batch :  1133 / 2202 accuracy:  0.84375
# Batch :  1134 / 2202 accuracy:  0.78125
# Batch :  1135 / 2202 accuracy:  0.84375
# Batch :  1136 / 2202 accuracy:  0.78125
# Batch :  1137 / 2202 accuracy:  0.8125
# Batch :  1138 / 2202 accuracy:  0.75
# Batch :  1139 / 2202 accuracy:  0.75
# Batch :  1140 / 2202 accuracy:  0.875
# Batch :  1141 / 2202 accuracy:  0.875
# Batch :  1142 / 2202 accuracy:  0.6875
# Batch :  1143 / 2202 accuracy:  0.65625
# Batch :  1144 / 2202 accuracy:  0.71875
# Batch :  1145 / 2202 accuracy:  0.65625
# Batch :  1146 / 2202 accuracy:  0.71875
# Batch :  1147 / 2202 accuracy:  0.78125
# Batch :  1148 / 2202 accuracy:  0.71875
# Batch :  1149 / 2202 accuracy:  0.8125
# Batch :  1150 / 2202 accuracy:  0.5625
# Batch :  1151 / 2202 accuracy:  0.75
# Batch :  1152 / 2202 accuracy:  0.78125
# Batch :  1153 / 2202 accuracy:  0.71875
# Batch :  1154 / 2202 accuracy:  0.75
# Batch :  1155 / 2202 accuracy:  0.75
# Batch :  1156 / 2202 accuracy:  0.75
# Batch :  1157 / 2202 accuracy:  0.71875
# Batch :  1158 / 2202 accuracy:  0.8125
# Batch :  1159 / 2202 accuracy:  0.71875
# Batch :  1160 / 2202 accuracy:  0.625
# Batch :  1161 / 2202 accuracy:  0.8125
# Batch :  1162 / 2202 accuracy:  0.75
# Batch :  1163 / 2202 accuracy:  0.8125
# Batch :  1164 / 2202 accuracy:  0.65625
# Batch :  1165 / 2202 accuracy:  0.625
# Batch :  1166 / 2202 accuracy:  0.78125
# Batch :  1167 / 2202 accuracy:  0.75
# Batch :  1168 / 2202 accuracy:  0.8125
# Batch :  1169 / 2202 accuracy:  0.78125
# Batch :  1170 / 2202 accuracy:  0.75
# Batch :  1171 / 2202 accuracy:  0.78125
# Batch :  1172 / 2202 accuracy:  0.875
# Batch :  1173 / 2202 accuracy:  0.75
# Batch :  1174 / 2202 accuracy:  0.75
# Batch :  1175 / 2202 accuracy:  0.875
# Batch :  1176 / 2202 accuracy:  0.875
# Batch :  1177 / 2202 accuracy:  0.65625
# Batch :  1178 / 2202 accuracy:  0.75
# Batch :  1179 / 2202 accuracy:  0.8125
# Batch :  1180 / 2202 accuracy:  0.9375
# Batch :  1181 / 2202 accuracy:  0.625
# Batch :  1182 / 2202 accuracy:  0.6875
# Batch :  1183 / 2202 accuracy:  0.90625
# Batch :  1184 / 2202 accuracy:  0.78125
# Batch :  1185 / 2202 accuracy:  0.71875
# Batch :  1186 / 2202 accuracy:  0.6875
# Batch :  1187 / 2202 accuracy:  0.71875
# Batch :  1188 / 2202 accuracy:  0.75
# Batch :  1189 / 2202 accuracy:  0.75
# Batch :  1190 / 2202 accuracy:  0.5625
# Batch :  1191 / 2202 accuracy:  0.84375
# Batch :  1192 / 2202 accuracy:  0.84375
# Batch :  1193 / 2202 accuracy:  0.75
# Batch :  1194 / 2202 accuracy:  0.90625
# Batch :  1195 / 2202 accuracy:  0.84375
# Batch :  1196 / 2202 accuracy:  0.9375
# Batch :  1197 / 2202 accuracy:  0.71875
# Batch :  1198 / 2202 accuracy:  0.78125
# Batch :  1199 / 2202 accuracy:  0.75
# Batch :  1200 / 2202 accuracy:  0.875
# Batch :  1201 / 2202 accuracy:  0.71875
# Batch :  1202 / 2202 accuracy:  0.84375
# Batch :  1203 / 2202 accuracy:  0.71875
# Batch :  1204 / 2202 accuracy:  0.8125
# Batch :  1205 / 2202 accuracy:  0.78125
# Batch :  1206 / 2202 accuracy:  0.65625
# Batch :  1207 / 2202 accuracy:  0.75
# Batch :  1208 / 2202 accuracy:  0.875
# Batch :  1209 / 2202 accuracy:  0.625
# Batch :  1210 / 2202 accuracy:  0.875
# Batch :  1211 / 2202 accuracy:  0.8125
# Batch :  1212 / 2202 accuracy:  0.6875
# Batch :  1213 / 2202 accuracy:  0.78125
# Batch :  1214 / 2202 accuracy:  0.65625
# Batch :  1215 / 2202 accuracy:  0.6875
# Batch :  1216 / 2202 accuracy:  0.8125
# Batch :  1217 / 2202 accuracy:  0.9375
# Batch :  1218 / 2202 accuracy:  0.5625
# Batch :  1219 / 2202 accuracy:  0.84375
# Batch :  1220 / 2202 accuracy:  0.78125
# Batch :  1221 / 2202 accuracy:  0.625
# Batch :  1222 / 2202 accuracy:  0.78125
# Batch :  1223 / 2202 accuracy:  0.75
# Batch :  1224 / 2202 accuracy:  0.8125
# Batch :  1225 / 2202 accuracy:  0.71875
# Batch :  1226 / 2202 accuracy:  0.78125
# Batch :  1227 / 2202 accuracy:  0.78125
# Batch :  1228 / 2202 accuracy:  0.90625
# Batch :  1229 / 2202 accuracy:  0.78125
# Batch :  1230 / 2202 accuracy:  0.78125
# Batch :  1231 / 2202 accuracy:  0.65625
# Batch :  1232 / 2202 accuracy:  0.625
# Batch :  1233 / 2202 accuracy:  0.75
# Batch :  1234 / 2202 accuracy:  0.75
# Batch :  1235 / 2202 accuracy:  0.8125
# Batch :  1236 / 2202 accuracy:  0.78125
# Batch :  1237 / 2202 accuracy:  0.6875
# Batch :  1238 / 2202 accuracy:  0.6875
# Batch :  1239 / 2202 accuracy:  0.75
# Batch :  1240 / 2202 accuracy:  0.84375
# Batch :  1241 / 2202 accuracy:  0.65625
# Batch :  1242 / 2202 accuracy:  0.78125
# Batch :  1243 / 2202 accuracy:  0.75
# Batch :  1244 / 2202 accuracy:  0.65625
# Batch :  1245 / 2202 accuracy:  0.75
# Batch :  1246 / 2202 accuracy:  0.84375
# Batch :  1247 / 2202 accuracy:  0.625
# Batch :  1248 / 2202 accuracy:  0.75
# Batch :  1249 / 2202 accuracy:  0.78125
# Batch :  1250 / 2202 accuracy:  0.65625
# Batch :  1251 / 2202 accuracy:  0.6875
# Batch :  1252 / 2202 accuracy:  0.78125
# Batch :  1253 / 2202 accuracy:  0.71875
# Batch :  1254 / 2202 accuracy:  0.78125
# Batch :  1255 / 2202 accuracy:  0.8125
# ...
# Batch :  1795 / 2202 accuracy:  0.8125
# Batch :  1796 / 2202 accuracy:  0.8125
# Batch :  1797 / 2202 accuracy:  0.625
# Batch :  1798 / 2202 accuracy:  0.625
# Batch :  1799 / 2202 accuracy:  0.75
# Batch :  1800 / 2202 accuracy:  0.65625
# Batch :  1801 / 2202 accuracy:  0.78125
# Batch :  1802 / 2202 accuracy:  0.75
# Batch :  1803 / 2202 accuracy:  0.78125
# Batch :  1804 / 2202 accuracy:  0.6875
# Batch :  1805 / 2202 accuracy:  0.84375
# Batch :  1806 / 2202 accuracy:  0.78125
# Batch :  1807 / 2202 accuracy:  0.71875
# Batch :  1808 / 2202 accuracy:  0.71875
# Batch :  1809 / 2202 accuracy:  0.71875
# Batch :  1810 / 2202 accuracy:  0.78125
# Batch :  1811 / 2202 accuracy:  0.78125
# Batch :  1812 / 2202 accuracy:  0.8125
# Batch :  1813 / 2202 accuracy:  0.8125
# Batch :  1814 / 2202 accuracy:  0.8125
# Batch :  1815 / 2202 accuracy:  0.65625
# Batch :  1816 / 2202 accuracy:  0.78125
# Batch :  1817 / 2202 accuracy:  0.65625
# Batch :  1818 / 2202 accuracy:  0.90625
# Batch :  1819 / 2202 accuracy:  0.625
# Batch :  1820 / 2202 accuracy:  0.8125
# Batch :  1821 / 2202 accuracy:  0.78125
# Batch :  1822 / 2202 accuracy:  0.5625
# Batch :  1823 / 2202 accuracy:  0.71875
# Batch :  1824 / 2202 accuracy:  0.75
# Batch :  1825 / 2202 accuracy:  0.78125
# Batch :  1826 / 2202 accuracy:  0.75
# Batch :  1827 / 2202 accuracy:  0.6875
# Batch :  1828 / 2202 accuracy:  0.78125
# Batch :  1829 / 2202 accuracy:  0.84375
# Batch :  1830 / 2202 accuracy:  0.625
# Batch :  1831 / 2202 accuracy:  0.75
# Batch :  1832 / 2202 accuracy:  0.65625
# Batch :  1833 / 2202 accuracy:  0.8125
# Batch :  1834 / 2202 accuracy:  0.75
# Batch :  1835 / 2202 accuracy:  0.65625
# Batch :  1836 / 2202 accuracy:  0.875
# Batch :  1837 / 2202 accuracy:  0.78125
# Batch :  1838 / 2202 accuracy:  0.6875
# Batch :  1839 / 2202 accuracy:  0.75
# Batch :  1840 / 2202 accuracy:  0.75
# Batch :  1841 / 2202 accuracy:  0.78125
# Batch :  1842 / 2202 accuracy:  0.75
# Batch :  1843 / 2202 accuracy:  0.6875
# Batch :  1844 / 2202 accuracy:  0.71875
# Batch :  1845 / 2202 accuracy:  0.71875
# Batch :  1846 / 2202 accuracy:  0.71875
# Batch :  1847 / 2202 accuracy:  0.75
# Batch :  1848 / 2202 accuracy:  0.8125
# Batch :  1849 / 2202 accuracy:  0.78125
# Batch :  1850 / 2202 accuracy:  0.6875
# Batch :  1851 / 2202 accuracy:  0.84375
# Batch :  1852 / 2202 accuracy:  0.625
# Batch :  1853 / 2202 accuracy:  0.71875
# Batch :  1854 / 2202 accuracy:  0.78125
# Batch :  1855 / 2202 accuracy:  0.71875
# Batch :  1856 / 2202 accuracy:  0.65625
# Batch :  1857 / 2202 accuracy:  0.8125
# Batch :  1858 / 2202 accuracy:  0.8125
# Batch :  1859 / 2202 accuracy:  0.78125
# Batch :  1860 / 2202 accuracy:  0.65625
# Batch :  1861 / 2202 accuracy:  0.6875
# Batch :  1862 / 2202 accuracy:  0.71875
# Batch :  1863 / 2202 accuracy:  0.78125
# Batch :  1864 / 2202 accuracy:  0.71875
# Batch :  1865 / 2202 accuracy:  0.78125
# Batch :  1866 / 2202 accuracy:  0.75
# Batch :  1867 / 2202 accuracy:  0.84375
# Batch :  1868 / 2202 accuracy:  0.6875
# Batch :  1869 / 2202 accuracy:  0.75
# Batch :  1870 / 2202 accuracy:  0.65625
# Batch :  1871 / 2202 accuracy:  0.6875
# Batch :  1872 / 2202 accuracy:  0.6875
# Batch :  1873 / 2202 accuracy:  0.75
# Batch :  1874 / 2202 accuracy:  0.78125
# Batch :  1875 / 2202 accuracy:  0.875
# Batch :  1876 / 2202 accuracy:  0.78125
# Batch :  1877 / 2202 accuracy:  0.65625
# Batch :  1878 / 2202 accuracy:  0.75
# Batch :  1879 / 2202 accuracy:  0.78125
# Batch :  1880 / 2202 accuracy:  0.90625
# Batch :  1881 / 2202 accuracy:  0.84375
# Batch :  1882 / 2202 accuracy:  0.8125
# Batch :  1883 / 2202 accuracy:  0.78125
# Batch :  1884 / 2202 accuracy:  0.71875
# Batch :  1885 / 2202 accuracy:  0.6875
# Batch :  1886 / 2202 accuracy:  0.6875
# Batch :  1887 / 2202 accuracy:  0.71875
# Batch :  1888 / 2202 accuracy:  0.8125
# Batch :  1889 / 2202 accuracy:  0.6875
# Batch :  1890 / 2202 accuracy:  0.71875
# Batch :  1891 / 2202 accuracy:  0.65625
# Batch :  1892 / 2202 accuracy:  0.71875
# Batch :  1893 / 2202 accuracy:  0.71875
# Batch :  1894 / 2202 accuracy:  0.6875
# Batch :  1895 / 2202 accuracy:  0.71875
# Batch :  1896 / 2202 accuracy:  0.65625
# Batch :  1897 / 2202 accuracy:  0.875
# Batch :  1898 / 2202 accuracy:  0.78125
# Batch :  1899 / 2202 accuracy:  0.75
# Batch :  1900 / 2202 accuracy:  0.78125
# Batch :  1901 / 2202 accuracy:  0.6875
# Batch :  1902 / 2202 accuracy:  0.5625
# Batch :  1903 / 2202 accuracy:  0.71875
# Batch :  1904 / 2202 accuracy:  0.71875
# Batch :  1905 / 2202 accuracy:  0.71875
# Batch :  1906 / 2202 accuracy:  0.78125
# Batch :  1907 / 2202 accuracy:  0.625
# Batch :  1908 / 2202 accuracy:  0.71875
# Batch :  1909 / 2202 accuracy:  0.78125
# Batch :  1910 / 2202 accuracy:  0.875
# Batch :  1911 / 2202 accuracy:  0.78125
# Batch :  1912 / 2202 accuracy:  0.59375
# Batch :  1913 / 2202 accuracy:  0.6875
# Batch :  1914 / 2202 accuracy:  0.6875
# Batch :  1915 / 2202 accuracy:  0.6875
# Batch :  1916 / 2202 accuracy:  0.625
# Batch :  1917 / 2202 accuracy:  0.78125
# Batch :  1918 / 2202 accuracy:  0.84375
# Batch :  1919 / 2202 accuracy:  0.875
# Batch :  1920 / 2202 accuracy:  0.8125
# Batch :  1921 / 2202 accuracy:  0.90625
# Batch :  1922 / 2202 accuracy:  0.875
# Batch :  1923 / 2202 accuracy:  0.65625
# Batch :  1924 / 2202 accuracy:  0.78125
# Batch :  1925 / 2202 accuracy:  0.65625
# Batch :  1926 / 2202 accuracy:  0.71875
# Batch :  1927 / 2202 accuracy:  0.65625
# Batch :  1928 / 2202 accuracy:  0.65625
# Batch :  1929 / 2202 accuracy:  0.75
# Batch :  1930 / 2202 accuracy:  0.6875
# Batch :  1931 / 2202 accuracy:  0.78125
# Batch :  1932 / 2202 accuracy:  0.78125
# Batch :  1933 / 2202 accuracy:  0.6875
# Batch :  1934 / 2202 accuracy:  0.75
# Batch :  1935 / 2202 accuracy:  0.78125
# Batch :  1936 / 2202 accuracy:  0.75
# Batch :  1937 / 2202 accuracy:  0.84375
# Batch :  1938 / 2202 accuracy:  0.78125
# Batch :  1939 / 2202 accuracy:  0.75
# Batch :  1940 / 2202 accuracy:  0.84375
# Batch :  1941 / 2202 accuracy:  0.6875
# Batch :  1942 / 2202 accuracy:  0.84375
# Batch :  1943 / 2202 accuracy:  0.8125
# Batch :  1944 / 2202 accuracy:  0.75
# Batch :  1945 / 2202 accuracy:  0.84375
# Batch :  1946 / 2202 accuracy:  0.84375
# Batch :  1947 / 2202 accuracy:  0.75
# Batch :  1948 / 2202 accuracy:  0.875
# Batch :  1949 / 2202 accuracy:  0.75
# Batch :  1950 / 2202 accuracy:  0.75
# Batch :  1951 / 2202 accuracy:  0.8125
# Batch :  1952 / 2202 accuracy:  0.65625
# Batch :  1953 / 2202 accuracy:  0.71875
# Batch :  1954 / 2202 accuracy:  0.6875
# Batch :  1955 / 2202 accuracy:  0.71875
# Batch :  1956 / 2202 accuracy:  0.8125
# Batch :  1957 / 2202 accuracy:  0.8125
# Batch :  1958 / 2202 accuracy:  0.78125
# Batch :  1959 / 2202 accuracy:  0.8125
# Batch :  1960 / 2202 accuracy:  0.78125
# Batch :  1961 / 2202 accuracy:  0.65625
# Batch :  1962 / 2202 accuracy:  0.8125
# Batch :  1963 / 2202 accuracy:  0.75
# Batch :  1964 / 2202 accuracy:  0.65625
# Batch :  1965 / 2202 accuracy:  0.71875
# Batch :  1966 / 2202 accuracy:  0.78125
# Batch :  1967 / 2202 accuracy:  0.78125
# Batch :  1968 / 2202 accuracy:  0.78125
# Batch :  1969 / 2202 accuracy:  0.71875
# Batch :  1970 / 2202 accuracy:  0.75
# Batch :  1971 / 2202 accuracy:  0.8125
# Batch :  1972 / 2202 accuracy:  0.71875
# Batch :  1973 / 2202 accuracy:  0.8125
# Batch :  1974 / 2202 accuracy:  0.84375
# Batch :  1975 / 2202 accuracy:  0.8125
# Batch :  1976 / 2202 accuracy:  0.78125
# Batch :  1977 / 2202 accuracy:  0.6875
# Batch :  1978 / 2202 accuracy:  0.65625
# Batch :  1979 / 2202 accuracy:  0.6875
# Batch :  1980 / 2202 accuracy:  0.78125
# Batch :  1981 / 2202 accuracy:  0.84375
# Batch :  1982 / 2202 accuracy:  0.8125
# Batch :  1983 / 2202 accuracy:  0.78125
# Batch :  1984 / 2202 accuracy:  0.78125
# Batch :  1985 / 2202 accuracy:  0.78125
# Batch :  1986 / 2202 accuracy:  0.75
# Batch :  1987 / 2202 accuracy:  0.75
# Batch :  1988 / 2202 accuracy:  0.59375
# Batch :  1989 / 2202 accuracy:  0.75
# Batch :  1990 / 2202 accuracy:  0.71875
# Batch :  1991 / 2202 accuracy:  0.75
# Batch :  1992 / 2202 accuracy:  0.78125
# Batch :  1993 / 2202 accuracy:  0.75
# Batch :  1994 / 2202 accuracy:  0.90625
# Batch :  1995 / 2202 accuracy:  0.78125
# Batch :  1996 / 2202 accuracy:  0.65625
# Batch :  1997 / 2202 accuracy:  0.875
# Batch :  1998 / 2202 accuracy:  0.71875
# Batch :  1999 / 2202 accuracy:  0.78125
# Batch :  2000 / 2202 accuracy:  0.78125
# Batch :  2001 / 2202 accuracy:  0.71875
# Batch :  2002 / 2202 accuracy:  0.78125
# Batch :  2003 / 2202 accuracy:  0.65625
# Batch :  2004 / 2202 accuracy:  0.65625
# Batch :  2005 / 2202 accuracy:  0.84375
# Batch :  2006 / 2202 accuracy:  0.75
# Batch :  2007 / 2202 accuracy:  0.8125
# Batch :  2008 / 2202 accuracy:  0.78125
# Batch :  2009 / 2202 accuracy:  0.6875
# Batch :  2010 / 2202 accuracy:  0.6875
# Batch :  2011 / 2202 accuracy:  0.75
# Batch :  2012 / 2202 accuracy:  0.875
# Batch :  2013 / 2202 accuracy:  0.6875
# Batch :  2014 / 2202 accuracy:  0.84375
# Batch :  2015 / 2202 accuracy:  0.8125
# Batch :  2016 / 2202 accuracy:  0.65625
# Batch :  2017 / 2202 accuracy:  0.875
# Batch :  2018 / 2202 accuracy:  0.78125
# Batch :  2019 / 2202 accuracy:  0.875
# Batch :  2020 / 2202 accuracy:  0.8125
# Batch :  2021 / 2202 accuracy:  0.71875
# Batch :  2022 / 2202 accuracy:  0.65625
# Batch :  2023 / 2202 accuracy:  0.6875
# Batch :  2024 / 2202 accuracy:  0.71875
# Batch :  2025 / 2202 accuracy:  0.78125
# Batch :  2026 / 2202 accuracy:  0.78125
# Batch :  2027 / 2202 accuracy:  0.78125
# Batch :  2028 / 2202 accuracy:  0.625
# Batch :  2029 / 2202 accuracy:  0.78125
# Batch :  2030 / 2202 accuracy:  0.625
# Batch :  2031 / 2202 accuracy:  0.71875
# Batch :  2032 / 2202 accuracy:  0.71875
# Batch :  2033 / 2202 accuracy:  0.625
# Batch :  2034 / 2202 accuracy:  0.59375
# Batch :  2035 / 2202 accuracy:  0.78125
# Batch :  2036 / 2202 accuracy:  0.8125
# Batch :  2037 / 2202 accuracy:  0.84375
# Batch :  2038 / 2202 accuracy:  0.65625
# Batch :  2039 / 2202 accuracy:  0.78125
# Batch :  2040 / 2202 accuracy:  0.75
# Batch :  2041 / 2202 accuracy:  0.90625
# Batch :  2042 / 2202 accuracy:  0.65625
# Batch :  2043 / 2202 accuracy:  0.625
# Batch :  2044 / 2202 accuracy:  0.84375
# Batch :  2045 / 2202 accuracy:  0.71875
# Batch :  2046 / 2202 accuracy:  0.90625
# Batch :  2047 / 2202 accuracy:  0.875
# Batch :  2048 / 2202 accuracy:  0.75
# Batch :  2049 / 2202 accuracy:  0.65625
# Batch :  2050 / 2202 accuracy:  0.8125
# Batch :  2051 / 2202 accuracy:  0.875
# Batch :  2052 / 2202 accuracy:  0.84375
# Batch :  2053 / 2202 accuracy:  0.6875
# Batch :  2054 / 2202 accuracy:  0.65625
# Batch :  2055 / 2202 accuracy:  0.75
# Batch :  2056 / 2202 accuracy:  0.78125
# Batch :  2057 / 2202 accuracy:  0.71875
# Batch :  2058 / 2202 accuracy:  0.71875
# Batch :  2059 / 2202 accuracy:  0.65625
# Batch :  2060 / 2202 accuracy:  0.71875
# Batch :  2061 / 2202 accuracy:  0.6875
# Batch :  2062 / 2202 accuracy:  0.78125
# Batch :  2063 / 2202 accuracy:  0.71875
# Batch :  2064 / 2202 accuracy:  0.65625
# Batch :  2065 / 2202 accuracy:  0.8125
# Batch :  2066 / 2202 accuracy:  0.8125
# Batch :  2067 / 2202 accuracy:  0.59375
# Batch :  2068 / 2202 accuracy:  0.8125
# Batch :  2069 / 2202 accuracy:  0.8125
# Batch :  2070 / 2202 accuracy:  0.75
# Batch :  2071 / 2202 accuracy:  0.65625
# Batch :  2072 / 2202 accuracy:  0.71875
# Batch :  2073 / 2202 accuracy:  0.75
# Batch :  2074 / 2202 accuracy:  0.78125
# Batch :  2075 / 2202 accuracy:  0.78125
# Batch :  2076 / 2202 accuracy:  0.71875
# Batch :  2077 / 2202 accuracy:  0.90625
# Batch :  2078 / 2202 accuracy:  0.71875
# Batch :  2079 / 2202 accuracy:  0.71875
# Batch :  2080 / 2202 accuracy:  0.65625
# Batch :  2081 / 2202 accuracy:  0.75
# Batch :  2082 / 2202 accuracy:  0.71875
# Batch :  2083 / 2202 accuracy:  0.6875
# Batch :  2084 / 2202 accuracy:  0.625
# Batch :  2085 / 2202 accuracy:  0.78125
# Batch :  2086 / 2202 accuracy:  0.65625
# Batch :  2087 / 2202 accuracy:  0.6875
# Batch :  2088 / 2202 accuracy:  0.75
# Batch :  2089 / 2202 accuracy:  0.84375
# Batch :  2090 / 2202 accuracy:  0.6875
# Batch :  2091 / 2202 accuracy:  0.75
# Batch :  2092 / 2202 accuracy:  0.75
# Batch :  2093 / 2202 accuracy:  1.0
# Batch :  2094 / 2202 accuracy:  0.84375
# Batch :  2095 / 2202 accuracy:  0.65625
# Batch :  2096 / 2202 accuracy:  0.8125
# Batch :  2097 / 2202 accuracy:  0.625
# Batch :  2098 / 2202 accuracy:  0.84375
# Batch :  2099 / 2202 accuracy:  0.8125
# Batch :  2100 / 2202 accuracy:  0.75
# Batch :  2101 / 2202 accuracy:  0.71875
# Batch :  2102 / 2202 accuracy:  0.71875
# Batch :  2103 / 2202 accuracy:  0.6875
# Batch :  2104 / 2202 accuracy:  0.8125
# Batch :  2105 / 2202 accuracy:  0.71875
# Batch :  2106 / 2202 accuracy:  0.65625
# Batch :  2107 / 2202 accuracy:  0.8125
# Batch :  2108 / 2202 accuracy:  0.84375
# Batch :  2109 / 2202 accuracy:  0.71875
# Batch :  2110 / 2202 accuracy:  0.75
# Batch :  2111 / 2202 accuracy:  0.65625
# Batch :  2112 / 2202 accuracy:  0.75
# Batch :  2113 / 2202 accuracy:  0.8125
# Batch :  2114 / 2202 accuracy:  0.90625
# Batch :  2115 / 2202 accuracy:  0.8125
# Batch :  2116 / 2202 accuracy:  0.65625
# Batch :  2117 / 2202 accuracy:  0.84375
# Batch :  2118 / 2202 accuracy:  0.6875
# Batch :  2119 / 2202 accuracy:  0.6875
# Batch :  2120 / 2202 accuracy:  0.8125
# Batch :  2121 / 2202 accuracy:  0.78125
# Batch :  2122 / 2202 accuracy:  0.75
# Batch :  2123 / 2202 accuracy:  0.875
# Batch :  2124 / 2202 accuracy:  0.75
# Batch :  2125 / 2202 accuracy:  0.78125
# Batch :  2126 / 2202 accuracy:  0.71875
# Batch :  2127 / 2202 accuracy:  0.75
# Batch :  2128 / 2202 accuracy:  0.875
# Batch :  2129 / 2202 accuracy:  0.75
# Batch :  2130 / 2202 accuracy:  0.75
# Batch :  2131 / 2202 accuracy:  0.75
# Batch :  2132 / 2202 accuracy:  0.84375
# Batch :  2133 / 2202 accuracy:  0.625
# Batch :  2134 / 2202 accuracy:  0.78125
# Batch :  2135 / 2202 accuracy:  0.84375
# Batch :  2136 / 2202 accuracy:  0.71875
# Batch :  2137 / 2202 accuracy:  0.78125
# Batch :  2138 / 2202 accuracy:  0.6875
# Batch :  2139 / 2202 accuracy:  0.75
# Batch :  2140 / 2202 accuracy:  0.90625
# Batch :  2141 / 2202 accuracy:  0.78125
# Batch :  2142 / 2202 accuracy:  0.8125
# Batch :  2143 / 2202 accuracy:  0.84375
# Batch :  2144 / 2202 accuracy:  0.625
# Batch :  2145 / 2202 accuracy:  0.75
# Batch :  2146 / 2202 accuracy:  0.78125
# Batch :  2147 / 2202 accuracy:  0.875
# Batch :  2148 / 2202 accuracy:  0.90625
# Batch :  2149 / 2202 accuracy:  0.71875
# Batch :  2150 / 2202 accuracy:  0.65625
# Batch :  2151 / 2202 accuracy:  0.65625
# Batch :  2152 / 2202 accuracy:  0.75
# Batch :  2153 / 2202 accuracy:  0.71875
# Batch :  2154 / 2202 accuracy:  0.78125
# Batch :  2155 / 2202 accuracy:  0.8125
# Batch :  2156 / 2202 accuracy:  0.84375
# Batch :  2157 / 2202 accuracy:  0.75
# Batch :  2158 / 2202 accuracy:  0.84375
# Batch :  2159 / 2202 accuracy:  0.625
# Batch :  2160 / 2202 accuracy:  0.71875
# Batch :  2161 / 2202 accuracy:  0.625
# Batch :  2162 / 2202 accuracy:  0.59375
# Batch :  2163 / 2202 accuracy:  0.71875
# Batch :  2164 / 2202 accuracy:  0.75
# Batch :  2165 / 2202 accuracy:  0.59375
# Batch :  2166 / 2202 accuracy:  0.75
# Batch :  2167 / 2202 accuracy:  0.875
# Batch :  2168 / 2202 accuracy:  0.8125
# Batch :  2169 / 2202 accuracy:  0.8125
# Batch :  2170 / 2202 accuracy:  0.5625
# Batch :  2171 / 2202 accuracy:  0.78125
# Batch :  2172 / 2202 accuracy:  0.8125
# Batch :  2173 / 2202 accuracy:  0.5625
# Batch :  2174 / 2202 accuracy:  0.71875
# Batch :  2175 / 2202 accuracy:  0.65625
# Batch :  2176 / 2202 accuracy:  0.75
# Batch :  2177 / 2202 accuracy:  0.78125
# Batch :  2178 / 2202 accuracy:  0.78125
# Batch :  2179 / 2202 accuracy:  0.84375
# Batch :  2180 / 2202 accuracy:  0.75
# Batch :  2181 / 2202 accuracy:  0.875
# Batch :  2182 / 2202 accuracy:  0.875
# Batch :  2183 / 2202 accuracy:  0.75
# Batch :  2184 / 2202 accuracy:  0.75
# Batch :  2185 / 2202 accuracy:  0.75
# Batch :  2186 / 2202 accuracy:  0.84375
# Batch :  2187 / 2202 accuracy:  0.90625
# Batch :  2188 / 2202 accuracy:  0.78125
# Batch :  2189 / 2202 accuracy:  0.71875
# Batch :  2190 / 2202 accuracy:  0.71875
# Batch :  2191 / 2202 accuracy:  0.65625
# Batch :  2192 / 2202 accuracy:  0.8125
# Batch :  2193 / 2202 accuracy:  0.84375
# Batch :  2194 / 2202 accuracy:  0.75
# Batch :  2195 / 2202 accuracy:  0.8125
# Batch :  2196 / 2202 accuracy:  0.625
# Batch :  2197 / 2202 accuracy:  0.625
# Batch :  2198 / 2202 accuracy:  0.78125
# Batch :  2199 / 2202 accuracy:  0.84375
# Batch :  2200 / 2202 accuracy:  0.65625
# Batch :  2201 / 2202 accuracy:  0.78125
# Batch :  2202 / 2202 accuracy:  0.71875
# accuracy: 0.7498723186925434

# %%
accuracy:  0.7890999913215637
accuracy:  0.6700000166893005
accuracy: 0.7498723186925434
